# %% [markdown]
# <a href="https://colab.research.google.com/github/getnetdemil/Deep-Learning-workshop/blob/master/Semantic_segmentation_%5Bcloze%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training a semantic segmentation network
#
# [Diego Ortego](https://sites.google.com/view/diegoortego/), [Insight Centre for Data Analytics](https://www.insight-centre.org/)
#
# [Dublin City University](https://www.dcu.ie/)
#
# ---
#
# This lab will illustrate how to specify and train a fully-convolutional neural networks for semantic segmentation. We will use a modified version of [PSPNet](https://arxiv.org/abs/1612.01105) architecture that consists of a backbone network (e.g. ResNet or VGG) with dilated convolutions in some layers, followed by a Pyramid Pooling Module to capture context information and the final convolutional classifier. Here, we will use a simplified version with ResNet-18 and a Pooling module (no pyramid) for faster training. We will use the [PASCAL VOC](http://host.robots.ox.ac.uk/pascal/VOC/voc2012/) dataset with lower resolution.

# %% [markdown]
# ### Instructions
#
# Anywhere you see a **???** in the code below, fill in in with the correct code.

# %%
import sys
print(sys.version)
# Out:
# 3.9.16 (main, Dec  7 2022, 01:11:51)
# [GCC 9.4.0]

# %% [markdown]
# # Import packages
# Find the PyTorch docs at https://pytorch.org/docs/stable/index.html
#
# Tutorials: https://pytorch.org/tutorials/

# %%
import torch
import torchvision
import torch.nn as nn
import torch.backends.cudnn as cudnn
import torch.utils.data as data
from torch import optim
from torchvision import datasets, transforms, models
import torch.nn.functional as F
import torchvision.transforms.functional as TF
from torch.utils.data import Dataset
from torchvision.datasets.utils import download_file_from_google_drive

from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import random
import sys
import argparse
import os
import time
from os.path import join
import csv

print('PyTorch version:', torch.__version__)
# Out:
# PyTorch version: 2.0.0+cu118

# %% [markdown]
# # Download dataset

# %%
# !gdown --id 1Osg2LUhhx_utC1C2qTXcL5LBt4slN8Ll
#!gdown --id 1pQGv0etFunhM7uZrc1mU1ijTtnCbGpla
# Out:
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1Osg2LUhhx_utC1C2qTXcL5LBt4slN8Ll
# To: /content/VOC2.tar
# 100% 3.35G/3.35G [00:46<00:00, 71.8MB/s]

# %%
# !tar xf VOC2.tar

# %%
# !rm VOC2.tar

# %% [markdown]
# ```
# # Tiene formato de código
# ```
#
# # Hyperparameters + Enable GPU acceleration

# %%
class configuration:
    def __init__(self):
        self.experiment_name = "prueba_SemanticSegPreTrainedLR0.001"
        self.pre_load = "True" ## Load dataset in memory
        self.pre_trained = "True"
        self.num_classes = 21
        self.ignore_label = 255
        self.lr = 0.001  # 0.001 if pretrained. 0.1 if scratch
        self.M = [] ##If training from scratch, reduce learning rate at some point
        self.batch_size = 16  # Training batch size
        self.test_batch_size = 4  # Test batch size
        self.epoch = 90 ## Number of epochs
        self.train_root = "./VOC"
        self.download = False
        self.seed = 271828


## Create arguments object
args = configuration()

# Make sure to enable GPU acceleration!
device = 'cuda'

# Set random seed for reproducability
torch.backends.cudnn.deterministic = True  # fix the GPU to deterministic mode
torch.manual_seed(args.seed)  # CPU seed
torch.cuda.manual_seed_all(args.seed)  # GPU seed
random.seed(args.seed)  # python seed for image transformation
np.random.seed(args.seed)

# %% [markdown]
# ## Define CNN architecture
# We are using a modified PSPnet with a ResNet-18 backbone (pretrained on ImageNet or not). Note that there are no fully-connected layers in the networks, i.e. it is fully-convolutional.

# %%
class PSPNetLite(nn.Module):
    def __init__(self, args, num_classes, pretrained=True, use_aux=True):
        super(PSPNetLite, self).__init__()
        self.use_aux = use_aux

        #### TO FILL: define pytorch default resnet-18 architecture (pretrained and not)
        if pretrained=="True":
            #resnet = ???
            resnet = models.resnet18(pretrained=True)
        else:
            #resnet = ???
            resnet = models.resnet18(pretrained=False)


        self.layer0 = nn.Sequential(resnet.conv1, resnet.bn1, resnet.relu, resnet.maxpool)
        self.layer1, self.layer2, self.layer3, self.layer4 = resnet.layer1, resnet.layer2, resnet.layer3, resnet.layer4

        for n, m in self.layer3.named_modules():
            if 'conv2' in n:
                m.dilation, m.padding, m.stride = (2, 2), (2, 2), (1, 1)
        for n, m in self.layer4.named_modules():
            if 'conv2' in n:
                m.dilation, m.padding, m.stride = (4, 4), (4, 4), (1, 1)

        ##Pooling module: simplification of Pyramid Pooling Module of PSPnet
        self.pm = nn.Sequential(
            nn.AdaptiveAvgPool2d(3),
            nn.Conv2d(512, 256, kernel_size=1, bias=False),
            nn.BatchNorm2d(256, momentum=.95),
            nn.ReLU(inplace=True)
        )

        ## Final classifier to get per-pixel predictions
        self.final = nn.Sequential(
            nn.Conv2d(768, 512, kernel_size=3, padding=1, bias=False),
            #nn.BatchNorm2d(???, momentum=.95),
            nn.BatchNorm2d(512, momentum=.95),
            nn.ReLU(inplace=True),
            nn.Dropout(0.1),
            nn.Conv2d(512, num_classes, kernel_size=1)
        )

    #### To fill: write the forward pass function:
    #### layer0 --> layer1 --> layer2 --> layer3 --> layer4--> pm --> final
    def forward(self, x):
        x_size = x.size()

        # x = ??? #layer0
        # x = ??? #layer1
        # x = ??? #layer2
        # x = ??? #layer3
        x = self.layer0(x)
        x = self.layer1(x)
        x = self.layer2(x)
        x = self.layer3(x)

        x1 = self.layer4(x)
        x2 = self.pm(x1)

        # Concatenate layer4 features with upsampled Pooling Module features
        x = self.final(torch.cat((x1, F.interpolate(x2, x1.size()[2:], mode='bilinear')), dim=1))
        ##return prediction after bilinear upsampling to original size
        return F.interpolate(x, x_size[2:], mode='bilinear')

# %% [markdown]
# ## Define dataset class
# Dataset: [PASCAL VOC](http://host.robots.ox.ac.uk/pascal/VOC/voc2012/) with over 8K (0.7K) images for training (validation). We use 224x224 resolution. Classes:
#
# 0=background, 1=aeroplane, 2=bicycle, 3=bird, 4=boat, 5=bottle, 6=bus, 7=car, 8=cat, 9=chair, 10=cow, 11=diningtable,
# 12=dog, 13=horse, 14=motorbike, 15=person # 16=potted plant, 17=sheep, 18=sofa, 19=train, 20=tv/monitor
#
#
# Method to make the dataset

# %%
def make_dataset(args, mode):
    assert mode in ['train', 'val', 'test']
    items = []
    if mode == 'train':
        img_path = os.path.join(args.train_root, 'benchmark_RELEASE', 'dataset', 'img')
        mask_path = os.path.join(args.train_root, 'benchmark_RELEASE', 'dataset', 'cls')
        data_list = [l.strip('\n') for l in open(os.path.join(
            args.train_root, 'benchmark_RELEASE', 'dataset', 'train.txt')).readlines()]
        for it in data_list:
            item = (os.path.join(img_path, it + '.jpg'), os.path.join(mask_path, it + '.mat'))
            items.append(item)
    elif mode == 'val':
        img_path = os.path.join(args.train_root, 'VOCdevkit', 'VOC2012', 'JPEGImages')
        mask_path = os.path.join(args.train_root, 'VOCdevkit', 'VOC2012', 'SegmentationClass')
        data_list = [l.strip('\n') for l in open(os.path.join(
            args.train_root, 'VOCdevkit', 'VOC2012', 'ImageSets', 'Segmentation', 'seg11valid.txt')).readlines()]
        for it in data_list:
            item = (os.path.join(img_path, it + '.jpg'), os.path.join(mask_path, it + '.png'))
            items.append(item)
    else:
        img_path = os.path.join(args.train_root, 'VOCdevkit (test)', 'VOC2012', 'JPEGImages')
        data_list = [l.strip('\n') for l in open(os.path.join(
            args.train_root, 'VOCdevkit (test)', 'VOC2012', 'ImageSets', 'Segmentation', 'test.txt')).readlines()]
        for it in data_list:
            items.append((img_path, it))
    return items


class VOC(data.Dataset):
    def __init__(self, args, mode, transform_input=None, transform_mask=None):
        self.args = args
        self.imgs = make_dataset(self.args, mode)
        if len(self.imgs) == 0:
            raise RuntimeError('Found 0 images, please check the data set')
        self.mode = mode

        self.transform_input = transform_input
        self.transform_mask = transform_mask

    def transform(self, image, mask):
        # Resize
        resize = transforms.Resize(size=(400, 400), interpolation=0)
        image = resize(image)
        mask = resize(mask)

        # Random crop
        i, j, h, w = transforms.RandomCrop.get_params(image, output_size=(224, 224))
        #### TO FILL: perform crops using random parameters from previous line.
        #### Note that crop parameters have to be the same for image and mask.
        #### If not, the ground-truth mask would not be aligned with its image content.
        # image = ???
        # mask = ???
        image = TF.crop(image, i, j, h, w)
        mask = TF.crop(mask, i, j, h, w)

        # Random horizontal flipping
        if random.random() > 0.5:
            image = TF.hflip(image)
            mask = TF.hflip(mask)

        return image, mask

    def test_transform(self, image, mask):
        # Resize
        resize = transforms.Resize(size=(400, 400), interpolation=0)
        image = resize(image)
        mask = resize(mask)

        # Random crop
        image = TF.center_crop(image, output_size=(224, 224))
        mask = TF.center_crop(mask, output_size=(224, 224))

        return image, mask

    def __getitem__(self, index):
        if self.mode == 'test':
            img_path, img_name = self.imgs[index]
            img = Image.open(os.path.join(img_path, img_name + '.jpg')).convert('RGB')
            if self.transform is not None:
                img = self.transform(img)
            return img_name, img

        img_path, mask_path = self.imgs[index]
        img = Image.open(img_path).convert('RGB')
        if self.mode == 'train':
            mask = sio.loadmat(mask_path)['GTcls']['Segmentation'][0][0]
            mask = Image.fromarray(mask.astype(np.uint8))
        else:
            mask = Image.open(mask_path)

        ##Joint transform
        if self.mode=="train":
            img, mask = self.transform(img, mask)
        else:
            img, mask = self.test_transform(img, mask)

        if self.transform_input is not None:
            img = self.transform_input(img)
        if self.transform_mask is not None:
            mask = 255*self.transform_mask(mask)

        return img, mask.long()

    def __len__(self):
        return len(self.imgs)

# %% [markdown]
# # PSPnetLite training epoch
# Per-pixel cross-entropy loss is computed and then aggregated to compute a loss per image.

# %%
def _fast_hist(label_pred, label_true, num_classes):
    mask = (label_true >= 0) & (label_true < num_classes)
    hist = np.bincount(
        num_classes * label_true[mask].astype(int) +
        label_pred[mask], minlength=num_classes ** 2).reshape(num_classes, num_classes)
    return hist

def train_SemanticSeg(args, model, device, train_loader, optimizer, epoch):
    # switch to train mode
    model.train()

    train_loss = []
    counter = 1

    criterion = nn.CrossEntropyLoss()
    gts_all, predictions_all = [], []

    for batch_idx, (images, mask) in enumerate(train_loader):

        images, mask = images.to(device), mask.to(device)

        #Forward pass
        outputs = model(images)


        #Aggregated per-pixel loss
        loss = criterion(outputs, mask.squeeze(1))
        train_loss.append(loss.item())

        # compute gradient and do SGD step
        optimizer.zero_grad()

        loss.backward()

        optimizer.step()


        if counter % 15 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}, Learning rate: {:.6f}'.format(
                epoch, int(counter * len(images)), len(train_loader.dataset),
                100. * counter / len(train_loader), loss.item(),
                optimizer.param_groups[0]['lr']))
        counter = counter + 1

    return sum(train_loss) / len(train_loss)#, mean_iu

# %% [markdown]
# # PSPnetLite validation

# %%
def testing(args, model, device, test_loader):

    # switch to train mode
    model.eval()
    loss_per_batch = []
    test_loss = 0


    ##We ignore index 255, i.e. object contours labeled with 255 in the val GT
    criterion = nn.CrossEntropyLoss(ignore_index=255)
    gts_all, predictions_all = [], []
    with torch.no_grad():
        for batch_idx, (images, mask) in enumerate(test_loader):

            images, mask = images.to(device), mask.to(device)

            outputs = model(images)

            #Aggregated per-pixel loss
            loss = criterion(outputs, mask.squeeze(1))
            loss_per_batch.append(loss.item())

            preds = outputs.data.max(1)[1].squeeze(1).squeeze(0).cpu().numpy()
            gts_all.append(mask.data.squeeze(0).cpu().numpy())
            predictions_all.append(preds)

    #test_loss /= len(test_loader.dataset)
    loss_per_epoch = [np.average(loss_per_batch)]

    ##Compute Mean Intersection over Union (mIoU)
    ##mIoU: Mean (of all classes) of intersection over union between prediction
    ##and ground-truth
    hist = np.zeros((args.num_classes, args.num_classes))
    for lp, lt in zip(predictions_all, gts_all):
        hist += _fast_hist(lp.flatten(), lt.flatten(), args.num_classes)

    iu = np.diag(hist) / (hist.sum(axis=1) + hist.sum(axis=0) - np.diag(hist))
    mean_iu = np.nanmean(iu)

    print('\nTest set ({:.0f}): Average loss: {:.4f}, mIoU: {:.4f}\n'.format(
        len(test_loader.dataset), loss_per_epoch[-1], mean_iu))

    return (loss_per_epoch, mean_iu)

# %% [markdown]
# # Image transformations
#
# Here only simple transformations are shown. This code performs transformations by default inside the dataset class. The decision for doing this is to easily handle that transformations have to be applied similarly to the image and the ground-truth (GT) segmentation mask. For example, if a crop is done to the image in a certain location, it has to be done in the same location in the GT mask.

# %%
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]


transform_input = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

transform_mask = transforms.ToTensor()

# %% [markdown]
# # Dataset, network, optimizer and scheduler creation

# %%
trainset = VOC(args, 'train', transform_input=transform_input, transform_mask=transform_mask)

train_loader = torch.utils.data.DataLoader(trainset, batch_size=args.batch_size, shuffle=True, num_workers=8, pin_memory=True)
testset = VOC(args, 'val', transform_input=transform_input, transform_mask=transform_mask)
test_loader = torch.utils.data.DataLoader(testset, batch_size=args.test_batch_size, shuffle=False, num_workers=8, pin_memory=True)

print('-------> Data loading')

model = PSPNetLite(args, num_classes=args.num_classes, pretrained=args.pre_trained).to(device)
print('Total params: %2.fM' % (sum(p.numel() for p in model.parameters()) / 1000000.0))

milestones = args.M
optimizer = optim.SGD(model.parameters(), lr=args.lr, momentum=0.9, weight_decay=1e-4)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=milestones, gamma=0.1)
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# -------> Data loading
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 151MB/s]
# Total params: 15M

# %% [markdown]
# # Training loop

# %%
loss_train_epoch = []
loss_test_epoch = []
acc_train_per_epoch = []
acc_test_per_epoch = []
new_labels = []

cont = 0

res_path = "./metrics_" + args.experiment_name

if not os.path.isdir(res_path):
    os.makedirs(res_path)

for epoch in range(1, args.epoch + 1):
    st = time.time()
    scheduler.step()
    # train for one epoch
    print("PSPnetLite training, epoch " + str(epoch))

    loss_per_epoch = train_SemanticSeg(args, model, device, train_loader, optimizer, epoch)

    loss_train_epoch += [loss_per_epoch]

    # test
    loss_per_epoch_test, acc_val_per_epoch_i = testing(args, model, device, test_loader)

    loss_test_epoch += loss_per_epoch_test
    acc_test_per_epoch += [acc_val_per_epoch_i]


    if epoch == 1:
        best_acc_val = acc_val_per_epoch_i

    else:
        if acc_val_per_epoch_i > best_acc_val:
            best_acc_val = acc_val_per_epoch_i

    if epoch == args.epoch:
        torch.save(model.state_dict(), "mySemanticSegModelPreTrained.pth")
        #torch.save(model.state_dict(), "mySemanticSegModelScratch.pth")

    np.save(res_path + '/' + 'LOSS_epoch_train.npy', np.asarray(loss_train_epoch))
    np.save(res_path + '/' + 'LOSS_epoch_val.npy', np.asarray(loss_test_epoch))

    # save accuracies:
    np.save(res_path + '/' + 'accuracy_per_epoch_val.npy', np.asarray(acc_test_per_epoch))

    cont += 1
# Out:
# PSPnetLite training, epoch 1
# /usr/local/lib/python3.9/dist-packages/torch/optim/lr_scheduler.py:139: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Train Epoch: 1 [240/8498 (3%)]	Loss: 1.762504, Learning rate: 0.001000
# Train Epoch: 1 [480/8498 (6%)]	Loss: 1.583159, Learning rate: 0.001000
# Train Epoch: 1 [720/8498 (8%)]	Loss: 1.458322, Learning rate: 0.001000
# Train Epoch: 1 [960/8498 (11%)]	Loss: 1.366443, Learning rate: 0.001000
# Train Epoch: 1 [1200/8498 (14%)]	Loss: 1.119457, Learning rate: 0.001000
# Train Epoch: 1 [1440/8498 (17%)]	Loss: 1.366912, Learning rate: 0.001000
# Train Epoch: 1 [1680/8498 (20%)]	Loss: 1.410136, Learning rate: 0.001000
# Train Epoch: 1 [1920/8498 (23%)]	Loss: 0.988838, Learning rate: 0.001000
# Train Epoch: 1 [2160/8498 (25%)]	Loss: 1.200086, Learning rate: 0.001000
# Train Epoch: 1 [2400/8498 (28%)]	Loss: 1.056494, Learning rate: 0.001000
# Train Epoch: 1 [2640/8498 (31%)]	Loss: 0.879382, Learning rate: 0.001000
# Train Epoch: 1 [2880/8498 (34%)]	Loss: 0.814418, Learning rate: 0.001000
# Train Epoch: 1 [3120/8498 (37%)]	Loss: 0.762917, Learning rate: 0.001000
# Train Epoch: 1 [3360/8498 (39%)]	Loss: 1.113757, Learning rate: 0.001000
# Train Epoch: 1 [3600/8498 (42%)]	Loss: 0.746493, Learning rate: 0.001000
# Train Epoch: 1 [3840/8498 (45%)]	Loss: 0.813615, Learning rate: 0.001000
# Train Epoch: 1 [4080/8498 (48%)]	Loss: 1.230502, Learning rate: 0.001000
# Train Epoch: 1 [4320/8498 (51%)]	Loss: 1.042071, Learning rate: 0.001000
# Train Epoch: 1 [4560/8498 (54%)]	Loss: 0.771952, Learning rate: 0.001000
# Train Epoch: 1 [4800/8498 (56%)]	Loss: 1.129078, Learning rate: 0.001000
# Train Epoch: 1 [5040/8498 (59%)]	Loss: 0.826065, Learning rate: 0.001000
# Train Epoch: 1 [5280/8498 (62%)]	Loss: 1.023080, Learning rate: 0.001000
# Train Epoch: 1 [5520/8498 (65%)]	Loss: 0.883468, Learning rate: 0.001000
# Train Epoch: 1 [5760/8498 (68%)]	Loss: 0.710810, Learning rate: 0.001000
# Train Epoch: 1 [6000/8498 (70%)]	Loss: 0.717922, Learning rate: 0.001000
# Train Epoch: 1 [6240/8498 (73%)]	Loss: 0.670271, Learning rate: 0.001000
# Train Epoch: 1 [6480/8498 (76%)]	Loss: 0.931992, Learning rate: 0.001000
# Train Epoch: 1 [6720/8498 (79%)]	Loss: 0.595918, Learning rate: 0.001000
# Train Epoch: 1 [6960/8498 (82%)]	Loss: 0.930835, Learning rate: 0.001000
# Train Epoch: 1 [7200/8498 (85%)]	Loss: 0.842923, Learning rate: 0.001000
# Train Epoch: 1 [7440/8498 (87%)]	Loss: 1.013064, Learning rate: 0.001000
# Train Epoch: 1 [7680/8498 (90%)]	Loss: 0.720663, Learning rate: 0.001000
# Train Epoch: 1 [7920/8498 (93%)]	Loss: 0.861313, Learning rate: 0.001000
# Train Epoch: 1 [8160/8498 (96%)]	Loss: 0.926483, Learning rate: 0.001000
# Train Epoch: 1 [8400/8498 (99%)]	Loss: 0.698393, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.7683, mIoU: 0.4536
#
# PSPnetLite training, epoch 2
# Train Epoch: 2 [240/8498 (3%)]	Loss: 0.584665, Learning rate: 0.001000
# Train Epoch: 2 [480/8498 (6%)]	Loss: 0.715383, Learning rate: 0.001000
# Train Epoch: 2 [720/8498 (8%)]	Loss: 0.916802, Learning rate: 0.001000
# Train Epoch: 2 [960/8498 (11%)]	Loss: 0.546150, Learning rate: 0.001000
# Train Epoch: 2 [1200/8498 (14%)]	Loss: 0.594666, Learning rate: 0.001000
# Train Epoch: 2 [1440/8498 (17%)]	Loss: 1.116392, Learning rate: 0.001000
# Train Epoch: 2 [1680/8498 (20%)]	Loss: 0.795914, Learning rate: 0.001000
# Train Epoch: 2 [1920/8498 (23%)]	Loss: 0.520565, Learning rate: 0.001000
# Train Epoch: 2 [2160/8498 (25%)]	Loss: 0.782180, Learning rate: 0.001000
# Train Epoch: 2 [2400/8498 (28%)]	Loss: 0.538806, Learning rate: 0.001000
# Train Epoch: 2 [2640/8498 (31%)]	Loss: 0.674876, Learning rate: 0.001000
# Train Epoch: 2 [2880/8498 (34%)]	Loss: 0.840729, Learning rate: 0.001000
# Train Epoch: 2 [3120/8498 (37%)]	Loss: 0.751684, Learning rate: 0.001000
# Train Epoch: 2 [3360/8498 (39%)]	Loss: 0.539223, Learning rate: 0.001000
# Train Epoch: 2 [3600/8498 (42%)]	Loss: 0.559098, Learning rate: 0.001000
# Train Epoch: 2 [3840/8498 (45%)]	Loss: 1.098023, Learning rate: 0.001000
# Train Epoch: 2 [4080/8498 (48%)]	Loss: 0.502554, Learning rate: 0.001000
# Train Epoch: 2 [4320/8498 (51%)]	Loss: 0.675173, Learning rate: 0.001000
# Train Epoch: 2 [4560/8498 (54%)]	Loss: 1.111176, Learning rate: 0.001000
# Train Epoch: 2 [4800/8498 (56%)]	Loss: 0.552186, Learning rate: 0.001000
# Train Epoch: 2 [5040/8498 (59%)]	Loss: 0.646266, Learning rate: 0.001000
# Train Epoch: 2 [5280/8498 (62%)]	Loss: 0.600703, Learning rate: 0.001000
# Train Epoch: 2 [5520/8498 (65%)]	Loss: 0.615526, Learning rate: 0.001000
# Train Epoch: 2 [5760/8498 (68%)]	Loss: 0.837176, Learning rate: 0.001000
# Train Epoch: 2 [6000/8498 (70%)]	Loss: 0.804034, Learning rate: 0.001000
# Train Epoch: 2 [6240/8498 (73%)]	Loss: 0.643236, Learning rate: 0.001000
# Train Epoch: 2 [6480/8498 (76%)]	Loss: 0.458412, Learning rate: 0.001000
# Train Epoch: 2 [6720/8498 (79%)]	Loss: 0.653157, Learning rate: 0.001000
# Train Epoch: 2 [6960/8498 (82%)]	Loss: 0.549456, Learning rate: 0.001000
# Train Epoch: 2 [7200/8498 (85%)]	Loss: 0.513496, Learning rate: 0.001000
# Train Epoch: 2 [7440/8498 (87%)]	Loss: 0.593185, Learning rate: 0.001000
# Train Epoch: 2 [7680/8498 (90%)]	Loss: 0.682108, Learning rate: 0.001000
# Train Epoch: 2 [7920/8498 (93%)]	Loss: 1.131429, Learning rate: 0.001000
# Train Epoch: 2 [8160/8498 (96%)]	Loss: 0.656747, Learning rate: 0.001000
# Train Epoch: 2 [8400/8498 (99%)]	Loss: 0.586938, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.7366, mIoU: 0.5057
#
# PSPnetLite training, epoch 3
# Train Epoch: 3 [240/8498 (3%)]	Loss: 0.479134, Learning rate: 0.001000
# Train Epoch: 3 [480/8498 (6%)]	Loss: 0.602743, Learning rate: 0.001000
# Train Epoch: 3 [720/8498 (8%)]	Loss: 0.815510, Learning rate: 0.001000
# Train Epoch: 3 [960/8498 (11%)]	Loss: 0.611303, Learning rate: 0.001000
# Train Epoch: 3 [1200/8498 (14%)]	Loss: 0.742225, Learning rate: 0.001000
# Train Epoch: 3 [1440/8498 (17%)]	Loss: 0.604504, Learning rate: 0.001000
# Train Epoch: 3 [1680/8498 (20%)]	Loss: 0.633001, Learning rate: 0.001000
# Train Epoch: 3 [1920/8498 (23%)]	Loss: 0.679825, Learning rate: 0.001000
# Train Epoch: 3 [2160/8498 (25%)]	Loss: 0.668379, Learning rate: 0.001000
# Train Epoch: 3 [2400/8498 (28%)]	Loss: 0.507091, Learning rate: 0.001000
# Train Epoch: 3 [2640/8498 (31%)]	Loss: 0.474039, Learning rate: 0.001000
# Train Epoch: 3 [2880/8498 (34%)]	Loss: 0.473090, Learning rate: 0.001000
# Train Epoch: 3 [3120/8498 (37%)]	Loss: 0.633962, Learning rate: 0.001000
# Train Epoch: 3 [3360/8498 (39%)]	Loss: 0.526957, Learning rate: 0.001000
# Train Epoch: 3 [3600/8498 (42%)]	Loss: 0.660256, Learning rate: 0.001000
# Train Epoch: 3 [3840/8498 (45%)]	Loss: 0.584038, Learning rate: 0.001000
# Train Epoch: 3 [4080/8498 (48%)]	Loss: 0.434457, Learning rate: 0.001000
# Train Epoch: 3 [4320/8498 (51%)]	Loss: 0.964721, Learning rate: 0.001000
# Train Epoch: 3 [4560/8498 (54%)]	Loss: 0.422171, Learning rate: 0.001000
# Train Epoch: 3 [4800/8498 (56%)]	Loss: 0.467821, Learning rate: 0.001000
# Train Epoch: 3 [5040/8498 (59%)]	Loss: 0.500409, Learning rate: 0.001000
# Train Epoch: 3 [5280/8498 (62%)]	Loss: 0.777288, Learning rate: 0.001000
# Train Epoch: 3 [5520/8498 (65%)]	Loss: 0.680732, Learning rate: 0.001000
# Train Epoch: 3 [5760/8498 (68%)]	Loss: 0.665539, Learning rate: 0.001000
# Train Epoch: 3 [6000/8498 (70%)]	Loss: 0.637936, Learning rate: 0.001000
# Train Epoch: 3 [6240/8498 (73%)]	Loss: 0.585475, Learning rate: 0.001000
# Train Epoch: 3 [6480/8498 (76%)]	Loss: 0.458946, Learning rate: 0.001000
# Train Epoch: 3 [6720/8498 (79%)]	Loss: 0.580043, Learning rate: 0.001000
# Train Epoch: 3 [6960/8498 (82%)]	Loss: 0.829996, Learning rate: 0.001000
# Train Epoch: 3 [7200/8498 (85%)]	Loss: 0.701546, Learning rate: 0.001000
# Train Epoch: 3 [7440/8498 (87%)]	Loss: 0.396576, Learning rate: 0.001000
# Train Epoch: 3 [7680/8498 (90%)]	Loss: 0.800691, Learning rate: 0.001000
# Train Epoch: 3 [7920/8498 (93%)]	Loss: 0.406918, Learning rate: 0.001000
# Train Epoch: 3 [8160/8498 (96%)]	Loss: 0.570553, Learning rate: 0.001000
# Train Epoch: 3 [8400/8498 (99%)]	Loss: 0.667752, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.7067, mIoU: 0.5285
#
# PSPnetLite training, epoch 4
# Train Epoch: 4 [240/8498 (3%)]	Loss: 0.733005, Learning rate: 0.001000
# Train Epoch: 4 [480/8498 (6%)]	Loss: 0.979828, Learning rate: 0.001000
# Train Epoch: 4 [720/8498 (8%)]	Loss: 0.545185, Learning rate: 0.001000
# Train Epoch: 4 [960/8498 (11%)]	Loss: 0.729990, Learning rate: 0.001000
# Train Epoch: 4 [1200/8498 (14%)]	Loss: 0.815900, Learning rate: 0.001000
# Train Epoch: 4 [1440/8498 (17%)]	Loss: 0.528639, Learning rate: 0.001000
# Train Epoch: 4 [1680/8498 (20%)]	Loss: 0.581734, Learning rate: 0.001000
# Train Epoch: 4 [1920/8498 (23%)]	Loss: 0.657709, Learning rate: 0.001000
# Train Epoch: 4 [2160/8498 (25%)]	Loss: 0.450699, Learning rate: 0.001000
# Train Epoch: 4 [2400/8498 (28%)]	Loss: 0.566421, Learning rate: 0.001000
# Train Epoch: 4 [2640/8498 (31%)]	Loss: 0.417549, Learning rate: 0.001000
# Train Epoch: 4 [2880/8498 (34%)]	Loss: 0.466198, Learning rate: 0.001000
# Train Epoch: 4 [3120/8498 (37%)]	Loss: 0.589956, Learning rate: 0.001000
# Train Epoch: 4 [3360/8498 (39%)]	Loss: 0.542126, Learning rate: 0.001000
# Train Epoch: 4 [3600/8498 (42%)]	Loss: 0.435820, Learning rate: 0.001000
# Train Epoch: 4 [3840/8498 (45%)]	Loss: 0.629149, Learning rate: 0.001000
# Train Epoch: 4 [4080/8498 (48%)]	Loss: 0.730564, Learning rate: 0.001000
# Train Epoch: 4 [4320/8498 (51%)]	Loss: 0.654379, Learning rate: 0.001000
# Train Epoch: 4 [4560/8498 (54%)]	Loss: 0.599996, Learning rate: 0.001000
# Train Epoch: 4 [4800/8498 (56%)]	Loss: 0.742797, Learning rate: 0.001000
# Train Epoch: 4 [5040/8498 (59%)]	Loss: 0.574243, Learning rate: 0.001000
# Train Epoch: 4 [5280/8498 (62%)]	Loss: 0.891336, Learning rate: 0.001000
# Train Epoch: 4 [5520/8498 (65%)]	Loss: 0.830552, Learning rate: 0.001000
# Train Epoch: 4 [5760/8498 (68%)]	Loss: 0.794080, Learning rate: 0.001000
# Train Epoch: 4 [6000/8498 (70%)]	Loss: 0.398803, Learning rate: 0.001000
# Train Epoch: 4 [6240/8498 (73%)]	Loss: 0.818599, Learning rate: 0.001000
# Train Epoch: 4 [6480/8498 (76%)]	Loss: 0.688736, Learning rate: 0.001000
# Train Epoch: 4 [6720/8498 (79%)]	Loss: 0.442978, Learning rate: 0.001000
# Train Epoch: 4 [6960/8498 (82%)]	Loss: 0.618715, Learning rate: 0.001000
# Train Epoch: 4 [7200/8498 (85%)]	Loss: 0.573101, Learning rate: 0.001000
# Train Epoch: 4 [7440/8498 (87%)]	Loss: 0.653270, Learning rate: 0.001000
# Train Epoch: 4 [7680/8498 (90%)]	Loss: 0.361905, Learning rate: 0.001000
# Train Epoch: 4 [7920/8498 (93%)]	Loss: 0.660755, Learning rate: 0.001000
# Train Epoch: 4 [8160/8498 (96%)]	Loss: 0.561204, Learning rate: 0.001000
# Train Epoch: 4 [8400/8498 (99%)]	Loss: 0.880936, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.6689, mIoU: 0.5529
#
# PSPnetLite training, epoch 5
# Train Epoch: 5 [240/8498 (3%)]	Loss: 0.557805, Learning rate: 0.001000
# Train Epoch: 5 [480/8498 (6%)]	Loss: 0.354093, Learning rate: 0.001000
# Train Epoch: 5 [720/8498 (8%)]	Loss: 0.949016, Learning rate: 0.001000
# Train Epoch: 5 [960/8498 (11%)]	Loss: 0.798326, Learning rate: 0.001000
# Train Epoch: 5 [1200/8498 (14%)]	Loss: 0.600464, Learning rate: 0.001000
# Train Epoch: 5 [1440/8498 (17%)]	Loss: 0.742331, Learning rate: 0.001000
# Train Epoch: 5 [1680/8498 (20%)]	Loss: 0.436081, Learning rate: 0.001000
# Train Epoch: 5 [1920/8498 (23%)]	Loss: 0.476132, Learning rate: 0.001000
# Train Epoch: 5 [2160/8498 (25%)]	Loss: 0.473017, Learning rate: 0.001000
# Train Epoch: 5 [2400/8498 (28%)]	Loss: 0.837704, Learning rate: 0.001000
# Train Epoch: 5 [2640/8498 (31%)]	Loss: 0.604876, Learning rate: 0.001000
# Train Epoch: 5 [2880/8498 (34%)]	Loss: 0.735953, Learning rate: 0.001000
# Train Epoch: 5 [3120/8498 (37%)]	Loss: 0.499507, Learning rate: 0.001000
# Train Epoch: 5 [3360/8498 (39%)]	Loss: 0.381314, Learning rate: 0.001000
# Train Epoch: 5 [3600/8498 (42%)]	Loss: 0.505238, Learning rate: 0.001000
# Train Epoch: 5 [3840/8498 (45%)]	Loss: 0.450638, Learning rate: 0.001000
# Train Epoch: 5 [4080/8498 (48%)]	Loss: 0.472044, Learning rate: 0.001000
# Train Epoch: 5 [4320/8498 (51%)]	Loss: 0.456809, Learning rate: 0.001000
# Train Epoch: 5 [4560/8498 (54%)]	Loss: 0.620841, Learning rate: 0.001000
# Train Epoch: 5 [4800/8498 (56%)]	Loss: 0.710945, Learning rate: 0.001000
# Train Epoch: 5 [5040/8498 (59%)]	Loss: 0.634180, Learning rate: 0.001000
# Train Epoch: 5 [5280/8498 (62%)]	Loss: 0.323150, Learning rate: 0.001000
# Train Epoch: 5 [5520/8498 (65%)]	Loss: 0.554550, Learning rate: 0.001000
# Train Epoch: 5 [5760/8498 (68%)]	Loss: 0.494992, Learning rate: 0.001000
# Train Epoch: 5 [6000/8498 (70%)]	Loss: 0.294695, Learning rate: 0.001000
# Train Epoch: 5 [6240/8498 (73%)]	Loss: 0.690068, Learning rate: 0.001000
# Train Epoch: 5 [6480/8498 (76%)]	Loss: 0.451246, Learning rate: 0.001000
# Train Epoch: 5 [6720/8498 (79%)]	Loss: 0.473616, Learning rate: 0.001000
# Train Epoch: 5 [6960/8498 (82%)]	Loss: 0.491856, Learning rate: 0.001000
# Train Epoch: 5 [7200/8498 (85%)]	Loss: 0.688642, Learning rate: 0.001000
# Train Epoch: 5 [7440/8498 (87%)]	Loss: 0.670827, Learning rate: 0.001000
# Train Epoch: 5 [7680/8498 (90%)]	Loss: 0.520173, Learning rate: 0.001000
# Train Epoch: 5 [7920/8498 (93%)]	Loss: 0.750931, Learning rate: 0.001000
# Train Epoch: 5 [8160/8498 (96%)]	Loss: 0.490862, Learning rate: 0.001000
# Train Epoch: 5 [8400/8498 (99%)]	Loss: 0.591183, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.6449, mIoU: 0.5645
#
# PSPnetLite training, epoch 6
# Train Epoch: 6 [240/8498 (3%)]	Loss: 0.390921, Learning rate: 0.001000
# Train Epoch: 6 [480/8498 (6%)]	Loss: 0.706248, Learning rate: 0.001000
# Train Epoch: 6 [720/8498 (8%)]	Loss: 0.537136, Learning rate: 0.001000
# Train Epoch: 6 [960/8498 (11%)]	Loss: 0.831865, Learning rate: 0.001000
# Train Epoch: 6 [1200/8498 (14%)]	Loss: 0.512424, Learning rate: 0.001000
# Train Epoch: 6 [1440/8498 (17%)]	Loss: 0.482164, Learning rate: 0.001000
# Train Epoch: 6 [1680/8498 (20%)]	Loss: 0.438774, Learning rate: 0.001000
# Train Epoch: 6 [1920/8498 (23%)]	Loss: 0.401495, Learning rate: 0.001000
# Train Epoch: 6 [2160/8498 (25%)]	Loss: 0.497077, Learning rate: 0.001000
# Train Epoch: 6 [2400/8498 (28%)]	Loss: 0.445274, Learning rate: 0.001000
# Train Epoch: 6 [2640/8498 (31%)]	Loss: 0.642675, Learning rate: 0.001000
# Train Epoch: 6 [2880/8498 (34%)]	Loss: 0.546124, Learning rate: 0.001000
# Train Epoch: 6 [3120/8498 (37%)]	Loss: 0.629947, Learning rate: 0.001000
# Train Epoch: 6 [3360/8498 (39%)]	Loss: 0.573529, Learning rate: 0.001000
# Train Epoch: 6 [3600/8498 (42%)]	Loss: 0.423191, Learning rate: 0.001000
# Train Epoch: 6 [3840/8498 (45%)]	Loss: 0.473216, Learning rate: 0.001000
# Train Epoch: 6 [4080/8498 (48%)]	Loss: 0.589048, Learning rate: 0.001000
# Train Epoch: 6 [4320/8498 (51%)]	Loss: 0.435366, Learning rate: 0.001000
# Train Epoch: 6 [4560/8498 (54%)]	Loss: 0.412473, Learning rate: 0.001000
# Train Epoch: 6 [4800/8498 (56%)]	Loss: 0.484193, Learning rate: 0.001000
# Train Epoch: 6 [5040/8498 (59%)]	Loss: 0.604430, Learning rate: 0.001000
# Train Epoch: 6 [5280/8498 (62%)]	Loss: 0.380280, Learning rate: 0.001000
# Train Epoch: 6 [5520/8498 (65%)]	Loss: 0.594566, Learning rate: 0.001000
# Train Epoch: 6 [5760/8498 (68%)]	Loss: 0.338069, Learning rate: 0.001000
# Train Epoch: 6 [6000/8498 (70%)]	Loss: 0.624622, Learning rate: 0.001000
# Train Epoch: 6 [6240/8498 (73%)]	Loss: 0.504422, Learning rate: 0.001000
# Train Epoch: 6 [6480/8498 (76%)]	Loss: 0.499369, Learning rate: 0.001000
# Train Epoch: 6 [6720/8498 (79%)]	Loss: 0.487858, Learning rate: 0.001000
# Train Epoch: 6 [6960/8498 (82%)]	Loss: 0.822519, Learning rate: 0.001000
# Train Epoch: 6 [7200/8498 (85%)]	Loss: 0.317731, Learning rate: 0.001000
# Train Epoch: 6 [7440/8498 (87%)]	Loss: 0.513253, Learning rate: 0.001000
# Train Epoch: 6 [7680/8498 (90%)]	Loss: 0.758767, Learning rate: 0.001000
# Train Epoch: 6 [7920/8498 (93%)]	Loss: 0.515310, Learning rate: 0.001000
# Train Epoch: 6 [8160/8498 (96%)]	Loss: 0.491044, Learning rate: 0.001000
# Train Epoch: 6 [8400/8498 (99%)]	Loss: 0.544609, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.6535, mIoU: 0.5413
#
# PSPnetLite training, epoch 7
# Train Epoch: 7 [240/8498 (3%)]	Loss: 0.413684, Learning rate: 0.001000
# Train Epoch: 7 [480/8498 (6%)]	Loss: 0.459746, Learning rate: 0.001000
# Train Epoch: 7 [720/8498 (8%)]	Loss: 0.369042, Learning rate: 0.001000
# Train Epoch: 7 [960/8498 (11%)]	Loss: 0.458461, Learning rate: 0.001000
# Train Epoch: 7 [1200/8498 (14%)]	Loss: 0.478804, Learning rate: 0.001000
# Train Epoch: 7 [1440/8498 (17%)]	Loss: 0.545852, Learning rate: 0.001000
# Train Epoch: 7 [1680/8498 (20%)]	Loss: 0.423748, Learning rate: 0.001000
# Train Epoch: 7 [1920/8498 (23%)]	Loss: 0.632803, Learning rate: 0.001000
# Train Epoch: 7 [2160/8498 (25%)]	Loss: 0.485612, Learning rate: 0.001000
# Train Epoch: 7 [2400/8498 (28%)]	Loss: 0.448355, Learning rate: 0.001000
# Train Epoch: 7 [2640/8498 (31%)]	Loss: 0.337068, Learning rate: 0.001000
# Train Epoch: 7 [2880/8498 (34%)]	Loss: 0.454237, Learning rate: 0.001000
# Train Epoch: 7 [3120/8498 (37%)]	Loss: 0.534050, Learning rate: 0.001000
# Train Epoch: 7 [3360/8498 (39%)]	Loss: 0.381816, Learning rate: 0.001000
# Train Epoch: 7 [3600/8498 (42%)]	Loss: 0.516532, Learning rate: 0.001000
# Train Epoch: 7 [3840/8498 (45%)]	Loss: 0.828810, Learning rate: 0.001000
# Train Epoch: 7 [4080/8498 (48%)]	Loss: 0.478453, Learning rate: 0.001000
# Train Epoch: 7 [4320/8498 (51%)]	Loss: 0.767926, Learning rate: 0.001000
# Train Epoch: 7 [4560/8498 (54%)]	Loss: 0.487211, Learning rate: 0.001000
# Train Epoch: 7 [4800/8498 (56%)]	Loss: 0.698075, Learning rate: 0.001000
# Train Epoch: 7 [5040/8498 (59%)]	Loss: 0.625691, Learning rate: 0.001000
# Train Epoch: 7 [5280/8498 (62%)]	Loss: 0.768763, Learning rate: 0.001000
# Train Epoch: 7 [5520/8498 (65%)]	Loss: 0.541213, Learning rate: 0.001000
# Train Epoch: 7 [5760/8498 (68%)]	Loss: 0.444265, Learning rate: 0.001000
# Train Epoch: 7 [6000/8498 (70%)]	Loss: 0.437313, Learning rate: 0.001000
# Train Epoch: 7 [6240/8498 (73%)]	Loss: 0.421053, Learning rate: 0.001000
# Train Epoch: 7 [6480/8498 (76%)]	Loss: 0.576280, Learning rate: 0.001000
# Train Epoch: 7 [6720/8498 (79%)]	Loss: 0.578553, Learning rate: 0.001000
# Train Epoch: 7 [6960/8498 (82%)]	Loss: 0.468866, Learning rate: 0.001000
# Train Epoch: 7 [7200/8498 (85%)]	Loss: 0.412632, Learning rate: 0.001000
# Train Epoch: 7 [7440/8498 (87%)]	Loss: 0.556965, Learning rate: 0.001000
# Train Epoch: 7 [7680/8498 (90%)]	Loss: 0.438276, Learning rate: 0.001000
# Train Epoch: 7 [7920/8498 (93%)]	Loss: 0.361123, Learning rate: 0.001000
# Train Epoch: 7 [8160/8498 (96%)]	Loss: 0.665578, Learning rate: 0.001000
# Train Epoch: 7 [8400/8498 (99%)]	Loss: 0.374938, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.6149, mIoU: 0.5604
#
# PSPnetLite training, epoch 8
# Train Epoch: 8 [240/8498 (3%)]	Loss: 0.458569, Learning rate: 0.001000
# Train Epoch: 8 [480/8498 (6%)]	Loss: 0.478105, Learning rate: 0.001000
# Train Epoch: 8 [720/8498 (8%)]	Loss: 0.341063, Learning rate: 0.001000
# Train Epoch: 8 [960/8498 (11%)]	Loss: 0.705962, Learning rate: 0.001000
# Train Epoch: 8 [1200/8498 (14%)]	Loss: 0.416393, Learning rate: 0.001000
# Train Epoch: 8 [1440/8498 (17%)]	Loss: 0.525195, Learning rate: 0.001000
# Train Epoch: 8 [1680/8498 (20%)]	Loss: 0.409302, Learning rate: 0.001000
# Train Epoch: 8 [1920/8498 (23%)]	Loss: 0.343865, Learning rate: 0.001000
# Train Epoch: 8 [2160/8498 (25%)]	Loss: 0.427130, Learning rate: 0.001000
# Train Epoch: 8 [2400/8498 (28%)]	Loss: 0.366825, Learning rate: 0.001000
# Train Epoch: 8 [2640/8498 (31%)]	Loss: 0.490082, Learning rate: 0.001000
# Train Epoch: 8 [2880/8498 (34%)]	Loss: 0.610968, Learning rate: 0.001000
# Train Epoch: 8 [3120/8498 (37%)]	Loss: 0.414133, Learning rate: 0.001000
# Train Epoch: 8 [3360/8498 (39%)]	Loss: 0.425518, Learning rate: 0.001000
# Train Epoch: 8 [3600/8498 (42%)]	Loss: 0.540570, Learning rate: 0.001000
# Train Epoch: 8 [3840/8498 (45%)]	Loss: 0.532890, Learning rate: 0.001000
# Train Epoch: 8 [4080/8498 (48%)]	Loss: 0.461670, Learning rate: 0.001000
# Train Epoch: 8 [4320/8498 (51%)]	Loss: 0.829375, Learning rate: 0.001000
# Train Epoch: 8 [4560/8498 (54%)]	Loss: 0.326169, Learning rate: 0.001000
# Train Epoch: 8 [4800/8498 (56%)]	Loss: 0.425143, Learning rate: 0.001000
# Train Epoch: 8 [5040/8498 (59%)]	Loss: 0.378641, Learning rate: 0.001000
# Train Epoch: 8 [5280/8498 (62%)]	Loss: 0.452888, Learning rate: 0.001000
# Train Epoch: 8 [5520/8498 (65%)]	Loss: 0.633671, Learning rate: 0.001000
# Train Epoch: 8 [5760/8498 (68%)]	Loss: 0.568564, Learning rate: 0.001000
# Train Epoch: 8 [6000/8498 (70%)]	Loss: 0.491414, Learning rate: 0.001000
# Train Epoch: 8 [6240/8498 (73%)]	Loss: 0.500314, Learning rate: 0.001000
# Train Epoch: 8 [6480/8498 (76%)]	Loss: 0.480968, Learning rate: 0.001000
# Train Epoch: 8 [6720/8498 (79%)]	Loss: 0.395574, Learning rate: 0.001000
# Train Epoch: 8 [6960/8498 (82%)]	Loss: 0.346511, Learning rate: 0.001000
# Train Epoch: 8 [7200/8498 (85%)]	Loss: 0.700485, Learning rate: 0.001000
# Train Epoch: 8 [7440/8498 (87%)]	Loss: 0.676139, Learning rate: 0.001000
# Train Epoch: 8 [7680/8498 (90%)]	Loss: 0.441353, Learning rate: 0.001000
# Train Epoch: 8 [7920/8498 (93%)]	Loss: 0.541432, Learning rate: 0.001000
# Train Epoch: 8 [8160/8498 (96%)]	Loss: 0.461011, Learning rate: 0.001000
# Train Epoch: 8 [8400/8498 (99%)]	Loss: 0.570811, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.6419, mIoU: 0.5659
#
# PSPnetLite training, epoch 9
# Train Epoch: 9 [240/8498 (3%)]	Loss: 0.437335, Learning rate: 0.001000
# Train Epoch: 9 [480/8498 (6%)]	Loss: 0.419630, Learning rate: 0.001000
# Train Epoch: 9 [720/8498 (8%)]	Loss: 0.442012, Learning rate: 0.001000
# Train Epoch: 9 [960/8498 (11%)]	Loss: 0.483252, Learning rate: 0.001000
# Train Epoch: 9 [1200/8498 (14%)]	Loss: 0.429699, Learning rate: 0.001000
# Train Epoch: 9 [1440/8498 (17%)]	Loss: 0.438660, Learning rate: 0.001000
# Train Epoch: 9 [1680/8498 (20%)]	Loss: 0.462108, Learning rate: 0.001000
# Train Epoch: 9 [1920/8498 (23%)]	Loss: 0.529992, Learning rate: 0.001000
# Train Epoch: 9 [2160/8498 (25%)]	Loss: 0.552724, Learning rate: 0.001000
# Train Epoch: 9 [2400/8498 (28%)]	Loss: 0.613488, Learning rate: 0.001000
# Train Epoch: 9 [2640/8498 (31%)]	Loss: 0.621085, Learning rate: 0.001000
# Train Epoch: 9 [2880/8498 (34%)]	Loss: 0.328295, Learning rate: 0.001000
# Train Epoch: 9 [3120/8498 (37%)]	Loss: 0.387553, Learning rate: 0.001000
# Train Epoch: 9 [3360/8498 (39%)]	Loss: 0.465467, Learning rate: 0.001000
# Train Epoch: 9 [3600/8498 (42%)]	Loss: 0.310293, Learning rate: 0.001000
# Train Epoch: 9 [3840/8498 (45%)]	Loss: 0.575478, Learning rate: 0.001000
# Train Epoch: 9 [4080/8498 (48%)]	Loss: 0.464876, Learning rate: 0.001000
# Train Epoch: 9 [4320/8498 (51%)]	Loss: 0.611759, Learning rate: 0.001000
# Train Epoch: 9 [4560/8498 (54%)]	Loss: 0.374112, Learning rate: 0.001000
# Train Epoch: 9 [4800/8498 (56%)]	Loss: 0.629866, Learning rate: 0.001000
# Train Epoch: 9 [5040/8498 (59%)]	Loss: 0.571563, Learning rate: 0.001000
# Train Epoch: 9 [5280/8498 (62%)]	Loss: 0.486058, Learning rate: 0.001000
# Train Epoch: 9 [5520/8498 (65%)]	Loss: 0.579373, Learning rate: 0.001000
# Train Epoch: 9 [5760/8498 (68%)]	Loss: 0.600459, Learning rate: 0.001000
# Train Epoch: 9 [6000/8498 (70%)]	Loss: 0.409765, Learning rate: 0.001000
# Train Epoch: 9 [6240/8498 (73%)]	Loss: 0.609867, Learning rate: 0.001000
# Train Epoch: 9 [6480/8498 (76%)]	Loss: 0.452792, Learning rate: 0.001000
# Train Epoch: 9 [6720/8498 (79%)]	Loss: 0.573778, Learning rate: 0.001000
# Train Epoch: 9 [6960/8498 (82%)]	Loss: 0.338311, Learning rate: 0.001000
# Train Epoch: 9 [7200/8498 (85%)]	Loss: 0.484040, Learning rate: 0.001000
# Train Epoch: 9 [7440/8498 (87%)]	Loss: 0.496133, Learning rate: 0.001000
# Train Epoch: 9 [7680/8498 (90%)]	Loss: 0.679321, Learning rate: 0.001000
# Train Epoch: 9 [7920/8498 (93%)]	Loss: 0.277927, Learning rate: 0.001000
# Train Epoch: 9 [8160/8498 (96%)]	Loss: 0.652098, Learning rate: 0.001000
# Train Epoch: 9 [8400/8498 (99%)]	Loss: 0.335740, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.6380, mIoU: 0.5634
#
# PSPnetLite training, epoch 10
# Train Epoch: 10 [240/8498 (3%)]	Loss: 0.376444, Learning rate: 0.001000
# Train Epoch: 10 [480/8498 (6%)]	Loss: 0.425112, Learning rate: 0.001000
# Train Epoch: 10 [720/8498 (8%)]	Loss: 0.518567, Learning rate: 0.001000
# Train Epoch: 10 [960/8498 (11%)]	Loss: 0.309037, Learning rate: 0.001000
# Train Epoch: 10 [1200/8498 (14%)]	Loss: 0.511202, Learning rate: 0.001000
# Train Epoch: 10 [1440/8498 (17%)]	Loss: 0.639454, Learning rate: 0.001000
# Train Epoch: 10 [1680/8498 (20%)]	Loss: 0.448804, Learning rate: 0.001000
# Train Epoch: 10 [1920/8498 (23%)]	Loss: 0.404134, Learning rate: 0.001000
# Train Epoch: 10 [2160/8498 (25%)]	Loss: 0.424110, Learning rate: 0.001000
# Train Epoch: 10 [2400/8498 (28%)]	Loss: 0.477300, Learning rate: 0.001000
# Train Epoch: 10 [2640/8498 (31%)]	Loss: 0.553797, Learning rate: 0.001000
# Train Epoch: 10 [2880/8498 (34%)]	Loss: 0.448445, Learning rate: 0.001000
# Train Epoch: 10 [3120/8498 (37%)]	Loss: 0.411800, Learning rate: 0.001000
# Train Epoch: 10 [3360/8498 (39%)]	Loss: 0.573514, Learning rate: 0.001000
# Train Epoch: 10 [3600/8498 (42%)]	Loss: 0.379919, Learning rate: 0.001000
# Train Epoch: 10 [3840/8498 (45%)]	Loss: 0.311281, Learning rate: 0.001000
# Train Epoch: 10 [4080/8498 (48%)]	Loss: 0.517040, Learning rate: 0.001000
# Train Epoch: 10 [4320/8498 (51%)]	Loss: 0.625422, Learning rate: 0.001000
# Train Epoch: 10 [4560/8498 (54%)]	Loss: 0.486662, Learning rate: 0.001000
# Train Epoch: 10 [4800/8498 (56%)]	Loss: 0.349404, Learning rate: 0.001000
# Train Epoch: 10 [5040/8498 (59%)]	Loss: 0.345955, Learning rate: 0.001000
# Train Epoch: 10 [5280/8498 (62%)]	Loss: 0.550881, Learning rate: 0.001000
# Train Epoch: 10 [5520/8498 (65%)]	Loss: 0.574448, Learning rate: 0.001000
# Train Epoch: 10 [5760/8498 (68%)]	Loss: 0.412466, Learning rate: 0.001000
# Train Epoch: 10 [6000/8498 (70%)]	Loss: 0.568691, Learning rate: 0.001000
# Train Epoch: 10 [6240/8498 (73%)]	Loss: 0.369443, Learning rate: 0.001000
# Train Epoch: 10 [6480/8498 (76%)]	Loss: 0.579376, Learning rate: 0.001000
# Train Epoch: 10 [6720/8498 (79%)]	Loss: 0.621715, Learning rate: 0.001000
# Train Epoch: 10 [6960/8498 (82%)]	Loss: 0.403441, Learning rate: 0.001000
# Train Epoch: 10 [7200/8498 (85%)]	Loss: 0.416150, Learning rate: 0.001000
# Train Epoch: 10 [7440/8498 (87%)]	Loss: 0.309386, Learning rate: 0.001000
# Train Epoch: 10 [7680/8498 (90%)]	Loss: 0.419554, Learning rate: 0.001000
# Train Epoch: 10 [7920/8498 (93%)]	Loss: 0.340855, Learning rate: 0.001000
# Train Epoch: 10 [8160/8498 (96%)]	Loss: 0.458740, Learning rate: 0.001000
# Train Epoch: 10 [8400/8498 (99%)]	Loss: 0.369301, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.6141, mIoU: 0.5789
#
# PSPnetLite training, epoch 11
# Train Epoch: 11 [240/8498 (3%)]	Loss: 0.468669, Learning rate: 0.001000
# Train Epoch: 11 [480/8498 (6%)]	Loss: 0.544904, Learning rate: 0.001000
# Train Epoch: 11 [720/8498 (8%)]	Loss: 0.692300, Learning rate: 0.001000
# Train Epoch: 11 [960/8498 (11%)]	Loss: 0.368399, Learning rate: 0.001000
# Train Epoch: 11 [1200/8498 (14%)]	Loss: 0.437974, Learning rate: 0.001000
# Train Epoch: 11 [1440/8498 (17%)]	Loss: 0.591930, Learning rate: 0.001000
# Train Epoch: 11 [1680/8498 (20%)]	Loss: 0.565016, Learning rate: 0.001000
# Train Epoch: 11 [1920/8498 (23%)]	Loss: 0.354799, Learning rate: 0.001000
# Train Epoch: 11 [2160/8498 (25%)]	Loss: 0.424571, Learning rate: 0.001000
# Train Epoch: 11 [2400/8498 (28%)]	Loss: 0.568648, Learning rate: 0.001000
# Train Epoch: 11 [2640/8498 (31%)]	Loss: 0.463818, Learning rate: 0.001000
# Train Epoch: 11 [2880/8498 (34%)]	Loss: 0.517304, Learning rate: 0.001000
# Train Epoch: 11 [3120/8498 (37%)]	Loss: 0.563444, Learning rate: 0.001000
# Train Epoch: 11 [3360/8498 (39%)]	Loss: 0.358982, Learning rate: 0.001000
# Train Epoch: 11 [3600/8498 (42%)]	Loss: 0.511185, Learning rate: 0.001000
# Train Epoch: 11 [3840/8498 (45%)]	Loss: 0.546659, Learning rate: 0.001000
# Train Epoch: 11 [4080/8498 (48%)]	Loss: 0.315981, Learning rate: 0.001000
# Train Epoch: 11 [4320/8498 (51%)]	Loss: 0.394099, Learning rate: 0.001000
# Train Epoch: 11 [4560/8498 (54%)]	Loss: 0.353705, Learning rate: 0.001000
# Train Epoch: 11 [4800/8498 (56%)]	Loss: 0.457234, Learning rate: 0.001000
# Train Epoch: 11 [5040/8498 (59%)]	Loss: 0.293909, Learning rate: 0.001000
# Train Epoch: 11 [5280/8498 (62%)]	Loss: 0.310420, Learning rate: 0.001000
# Train Epoch: 11 [5520/8498 (65%)]	Loss: 0.333216, Learning rate: 0.001000
# Train Epoch: 11 [5760/8498 (68%)]	Loss: 0.399302, Learning rate: 0.001000
# Train Epoch: 11 [6000/8498 (70%)]	Loss: 0.450904, Learning rate: 0.001000
# Train Epoch: 11 [6240/8498 (73%)]	Loss: 0.549426, Learning rate: 0.001000
# Train Epoch: 11 [6480/8498 (76%)]	Loss: 0.516379, Learning rate: 0.001000
# Train Epoch: 11 [6720/8498 (79%)]	Loss: 0.421656, Learning rate: 0.001000
# Train Epoch: 11 [6960/8498 (82%)]	Loss: 0.661561, Learning rate: 0.001000
# Train Epoch: 11 [7200/8498 (85%)]	Loss: 0.401305, Learning rate: 0.001000
# Train Epoch: 11 [7440/8498 (87%)]	Loss: 0.471191, Learning rate: 0.001000
# Train Epoch: 11 [7680/8498 (90%)]	Loss: 0.457519, Learning rate: 0.001000
# Train Epoch: 11 [7920/8498 (93%)]	Loss: 0.567777, Learning rate: 0.001000
# Train Epoch: 11 [8160/8498 (96%)]	Loss: 0.519225, Learning rate: 0.001000
# Train Epoch: 11 [8400/8498 (99%)]	Loss: 0.434160, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.6473, mIoU: 0.5553
#
# PSPnetLite training, epoch 12
# Train Epoch: 12 [240/8498 (3%)]	Loss: 0.375467, Learning rate: 0.001000
# Train Epoch: 12 [480/8498 (6%)]	Loss: 0.555352, Learning rate: 0.001000
# Train Epoch: 12 [720/8498 (8%)]	Loss: 0.458963, Learning rate: 0.001000
# Train Epoch: 12 [960/8498 (11%)]	Loss: 0.476564, Learning rate: 0.001000
# Train Epoch: 12 [1200/8498 (14%)]	Loss: 0.378868, Learning rate: 0.001000
# Train Epoch: 12 [1440/8498 (17%)]	Loss: 0.444881, Learning rate: 0.001000
# Train Epoch: 12 [1680/8498 (20%)]	Loss: 0.514790, Learning rate: 0.001000
# Train Epoch: 12 [1920/8498 (23%)]	Loss: 0.650808, Learning rate: 0.001000
# Train Epoch: 12 [2160/8498 (25%)]	Loss: 0.329239, Learning rate: 0.001000
# Train Epoch: 12 [2400/8498 (28%)]	Loss: 0.371017, Learning rate: 0.001000
# Train Epoch: 12 [2640/8498 (31%)]	Loss: 0.274434, Learning rate: 0.001000
# Train Epoch: 12 [2880/8498 (34%)]	Loss: 0.346414, Learning rate: 0.001000
# Train Epoch: 12 [3120/8498 (37%)]	Loss: 0.444775, Learning rate: 0.001000
# Train Epoch: 12 [3360/8498 (39%)]	Loss: 0.494236, Learning rate: 0.001000
# Train Epoch: 12 [3600/8498 (42%)]	Loss: 0.383439, Learning rate: 0.001000
# Train Epoch: 12 [3840/8498 (45%)]	Loss: 0.482677, Learning rate: 0.001000
# Train Epoch: 12 [4080/8498 (48%)]	Loss: 0.472864, Learning rate: 0.001000
# Train Epoch: 12 [4320/8498 (51%)]	Loss: 0.437987, Learning rate: 0.001000
# Train Epoch: 12 [4560/8498 (54%)]	Loss: 0.557440, Learning rate: 0.001000
# Train Epoch: 12 [4800/8498 (56%)]	Loss: 0.474511, Learning rate: 0.001000
# Train Epoch: 12 [5040/8498 (59%)]	Loss: 0.397965, Learning rate: 0.001000
# Train Epoch: 12 [5280/8498 (62%)]	Loss: 0.270143, Learning rate: 0.001000
# Train Epoch: 12 [5520/8498 (65%)]	Loss: 0.517160, Learning rate: 0.001000
# Train Epoch: 12 [5760/8498 (68%)]	Loss: 0.503200, Learning rate: 0.001000
# Train Epoch: 12 [6000/8498 (70%)]	Loss: 0.311687, Learning rate: 0.001000
# Train Epoch: 12 [6240/8498 (73%)]	Loss: 0.301864, Learning rate: 0.001000
# Train Epoch: 12 [6480/8498 (76%)]	Loss: 0.442277, Learning rate: 0.001000
# Train Epoch: 12 [6720/8498 (79%)]	Loss: 0.400970, Learning rate: 0.001000
# Train Epoch: 12 [6960/8498 (82%)]	Loss: 0.382728, Learning rate: 0.001000
# Train Epoch: 12 [7200/8498 (85%)]	Loss: 0.610544, Learning rate: 0.001000
# Train Epoch: 12 [7440/8498 (87%)]	Loss: 0.295443, Learning rate: 0.001000
# Train Epoch: 12 [7680/8498 (90%)]	Loss: 0.296400, Learning rate: 0.001000
# Train Epoch: 12 [7920/8498 (93%)]	Loss: 0.700365, Learning rate: 0.001000
# Train Epoch: 12 [8160/8498 (96%)]	Loss: 0.368825, Learning rate: 0.001000
# Train Epoch: 12 [8400/8498 (99%)]	Loss: 0.421078, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.6357, mIoU: 0.5761
#
# PSPnetLite training, epoch 13
# Train Epoch: 13 [240/8498 (3%)]	Loss: 0.498520, Learning rate: 0.001000
# Train Epoch: 13 [480/8498 (6%)]	Loss: 0.422983, Learning rate: 0.001000
# Train Epoch: 13 [720/8498 (8%)]	Loss: 0.424780, Learning rate: 0.001000
# Train Epoch: 13 [960/8498 (11%)]	Loss: 0.441177, Learning rate: 0.001000
# Train Epoch: 13 [1200/8498 (14%)]	Loss: 0.409650, Learning rate: 0.001000
# Train Epoch: 13 [1440/8498 (17%)]	Loss: 0.407201, Learning rate: 0.001000
# Train Epoch: 13 [1680/8498 (20%)]	Loss: 0.361953, Learning rate: 0.001000
# Train Epoch: 13 [1920/8498 (23%)]	Loss: 0.393863, Learning rate: 0.001000
# Train Epoch: 13 [2160/8498 (25%)]	Loss: 0.418640, Learning rate: 0.001000
# Train Epoch: 13 [2400/8498 (28%)]	Loss: 0.574583, Learning rate: 0.001000
# Train Epoch: 13 [2640/8498 (31%)]	Loss: 0.383688, Learning rate: 0.001000
# Train Epoch: 13 [2880/8498 (34%)]	Loss: 0.410417, Learning rate: 0.001000
# Train Epoch: 13 [3120/8498 (37%)]	Loss: 0.456952, Learning rate: 0.001000
# Train Epoch: 13 [3360/8498 (39%)]	Loss: 0.420278, Learning rate: 0.001000
# Train Epoch: 13 [3600/8498 (42%)]	Loss: 0.408870, Learning rate: 0.001000
# Train Epoch: 13 [3840/8498 (45%)]	Loss: 0.401080, Learning rate: 0.001000
# Train Epoch: 13 [4080/8498 (48%)]	Loss: 0.491711, Learning rate: 0.001000
# Train Epoch: 13 [4320/8498 (51%)]	Loss: 0.483842, Learning rate: 0.001000
# Train Epoch: 13 [4560/8498 (54%)]	Loss: 0.558212, Learning rate: 0.001000
# Train Epoch: 13 [4800/8498 (56%)]	Loss: 0.376125, Learning rate: 0.001000
# Train Epoch: 13 [5040/8498 (59%)]	Loss: 0.320400, Learning rate: 0.001000
# Train Epoch: 13 [5280/8498 (62%)]	Loss: 0.529116, Learning rate: 0.001000
# Train Epoch: 13 [5520/8498 (65%)]	Loss: 0.490576, Learning rate: 0.001000
# Train Epoch: 13 [5760/8498 (68%)]	Loss: 0.483356, Learning rate: 0.001000
# Train Epoch: 13 [6000/8498 (70%)]	Loss: 0.411364, Learning rate: 0.001000
# Train Epoch: 13 [6240/8498 (73%)]	Loss: 0.385604, Learning rate: 0.001000
# Train Epoch: 13 [6480/8498 (76%)]	Loss: 0.440627, Learning rate: 0.001000
# Train Epoch: 13 [6720/8498 (79%)]	Loss: 0.513225, Learning rate: 0.001000
# Train Epoch: 13 [6960/8498 (82%)]	Loss: 0.585751, Learning rate: 0.001000
# Train Epoch: 13 [7200/8498 (85%)]	Loss: 0.432333, Learning rate: 0.001000
# Train Epoch: 13 [7440/8498 (87%)]	Loss: 0.441100, Learning rate: 0.001000
# Train Epoch: 13 [7680/8498 (90%)]	Loss: 0.325678, Learning rate: 0.001000
# Train Epoch: 13 [7920/8498 (93%)]	Loss: 0.459694, Learning rate: 0.001000
# Train Epoch: 13 [8160/8498 (96%)]	Loss: 0.345737, Learning rate: 0.001000
# Train Epoch: 13 [8400/8498 (99%)]	Loss: 0.579638, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.6601, mIoU: 0.5650
#
# PSPnetLite training, epoch 14
# Train Epoch: 14 [240/8498 (3%)]	Loss: 0.343878, Learning rate: 0.001000
# Train Epoch: 14 [480/8498 (6%)]	Loss: 0.366769, Learning rate: 0.001000
# Train Epoch: 14 [720/8498 (8%)]	Loss: 0.322188, Learning rate: 0.001000
# Train Epoch: 14 [960/8498 (11%)]	Loss: 0.520320, Learning rate: 0.001000
# Train Epoch: 14 [1200/8498 (14%)]	Loss: 0.361267, Learning rate: 0.001000
# Train Epoch: 14 [1440/8498 (17%)]	Loss: 0.353942, Learning rate: 0.001000
# Train Epoch: 14 [1680/8498 (20%)]	Loss: 0.564302, Learning rate: 0.001000
# Train Epoch: 14 [1920/8498 (23%)]	Loss: 0.368441, Learning rate: 0.001000
# Train Epoch: 14 [2160/8498 (25%)]	Loss: 0.293452, Learning rate: 0.001000
# Train Epoch: 14 [2400/8498 (28%)]	Loss: 0.325395, Learning rate: 0.001000
# Train Epoch: 14 [2640/8498 (31%)]	Loss: 0.377201, Learning rate: 0.001000
# Train Epoch: 14 [2880/8498 (34%)]	Loss: 0.449318, Learning rate: 0.001000
# Train Epoch: 14 [3120/8498 (37%)]	Loss: 0.337212, Learning rate: 0.001000
# Train Epoch: 14 [3360/8498 (39%)]	Loss: 0.378989, Learning rate: 0.001000
# Train Epoch: 14 [3600/8498 (42%)]	Loss: 0.332611, Learning rate: 0.001000
# Train Epoch: 14 [3840/8498 (45%)]	Loss: 0.456980, Learning rate: 0.001000
# Train Epoch: 14 [4080/8498 (48%)]	Loss: 0.354136, Learning rate: 0.001000
# Train Epoch: 14 [4320/8498 (51%)]	Loss: 0.598058, Learning rate: 0.001000
# Train Epoch: 14 [4560/8498 (54%)]	Loss: 0.317863, Learning rate: 0.001000
# Train Epoch: 14 [4800/8498 (56%)]	Loss: 0.414197, Learning rate: 0.001000
# Train Epoch: 14 [5040/8498 (59%)]	Loss: 0.468282, Learning rate: 0.001000
# Train Epoch: 14 [5280/8498 (62%)]	Loss: 0.384150, Learning rate: 0.001000
# Train Epoch: 14 [5520/8498 (65%)]	Loss: 0.437725, Learning rate: 0.001000
# Train Epoch: 14 [5760/8498 (68%)]	Loss: 0.347798, Learning rate: 0.001000
# Train Epoch: 14 [6000/8498 (70%)]	Loss: 0.352823, Learning rate: 0.001000
# Train Epoch: 14 [6240/8498 (73%)]	Loss: 0.424260, Learning rate: 0.001000
# Train Epoch: 14 [6480/8498 (76%)]	Loss: 0.715230, Learning rate: 0.001000
# Train Epoch: 14 [6720/8498 (79%)]	Loss: 0.472942, Learning rate: 0.001000
# Train Epoch: 14 [6960/8498 (82%)]	Loss: 0.645011, Learning rate: 0.001000
# Train Epoch: 14 [7200/8498 (85%)]	Loss: 0.464647, Learning rate: 0.001000
# Train Epoch: 14 [7440/8498 (87%)]	Loss: 0.405346, Learning rate: 0.001000
# Train Epoch: 14 [7680/8498 (90%)]	Loss: 0.505997, Learning rate: 0.001000
# Train Epoch: 14 [7920/8498 (93%)]	Loss: 0.630426, Learning rate: 0.001000
# Train Epoch: 14 [8160/8498 (96%)]	Loss: 0.426325, Learning rate: 0.001000
# Train Epoch: 14 [8400/8498 (99%)]	Loss: 0.282142, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.5837, mIoU: 0.5832
#
# PSPnetLite training, epoch 15
# Train Epoch: 15 [240/8498 (3%)]	Loss: 0.368405, Learning rate: 0.001000
# Train Epoch: 15 [480/8498 (6%)]	Loss: 0.399365, Learning rate: 0.001000
# Train Epoch: 15 [720/8498 (8%)]	Loss: 0.515785, Learning rate: 0.001000
# Train Epoch: 15 [960/8498 (11%)]	Loss: 0.292323, Learning rate: 0.001000
# Train Epoch: 15 [1200/8498 (14%)]	Loss: 0.498920, Learning rate: 0.001000
# Train Epoch: 15 [1440/8498 (17%)]	Loss: 0.344539, Learning rate: 0.001000
# Train Epoch: 15 [1680/8498 (20%)]	Loss: 0.344385, Learning rate: 0.001000
# Train Epoch: 15 [1920/8498 (23%)]	Loss: 0.407963, Learning rate: 0.001000
# Train Epoch: 15 [2160/8498 (25%)]	Loss: 0.604089, Learning rate: 0.001000
# Train Epoch: 15 [2400/8498 (28%)]	Loss: 0.408707, Learning rate: 0.001000
# Train Epoch: 15 [2640/8498 (31%)]	Loss: 0.314847, Learning rate: 0.001000
# Train Epoch: 15 [2880/8498 (34%)]	Loss: 0.380811, Learning rate: 0.001000
# Train Epoch: 15 [3120/8498 (37%)]	Loss: 0.383362, Learning rate: 0.001000
# Train Epoch: 15 [3360/8498 (39%)]	Loss: 0.347053, Learning rate: 0.001000
# Train Epoch: 15 [3600/8498 (42%)]	Loss: 0.508484, Learning rate: 0.001000
# Train Epoch: 15 [3840/8498 (45%)]	Loss: 0.515597, Learning rate: 0.001000
# Train Epoch: 15 [4080/8498 (48%)]	Loss: 0.383936, Learning rate: 0.001000
# Train Epoch: 15 [4320/8498 (51%)]	Loss: 0.342500, Learning rate: 0.001000
# Train Epoch: 15 [4560/8498 (54%)]	Loss: 0.399037, Learning rate: 0.001000
# Train Epoch: 15 [4800/8498 (56%)]	Loss: 0.303594, Learning rate: 0.001000
# Train Epoch: 15 [5040/8498 (59%)]	Loss: 0.458108, Learning rate: 0.001000
# Train Epoch: 15 [5280/8498 (62%)]	Loss: 0.457184, Learning rate: 0.001000
# Train Epoch: 15 [5520/8498 (65%)]	Loss: 0.507444, Learning rate: 0.001000
# Train Epoch: 15 [5760/8498 (68%)]	Loss: 0.409327, Learning rate: 0.001000
# Train Epoch: 15 [6000/8498 (70%)]	Loss: 0.435280, Learning rate: 0.001000
# Train Epoch: 15 [6240/8498 (73%)]	Loss: 0.521374, Learning rate: 0.001000
# Train Epoch: 15 [6480/8498 (76%)]	Loss: 0.327883, Learning rate: 0.001000
# Train Epoch: 15 [6720/8498 (79%)]	Loss: 0.558663, Learning rate: 0.001000
# Train Epoch: 15 [6960/8498 (82%)]	Loss: 0.549969, Learning rate: 0.001000
# Train Epoch: 15 [7200/8498 (85%)]	Loss: 0.370988, Learning rate: 0.001000
# Train Epoch: 15 [7440/8498 (87%)]	Loss: 0.330604, Learning rate: 0.001000
# Train Epoch: 15 [7680/8498 (90%)]	Loss: 0.350762, Learning rate: 0.001000
# Train Epoch: 15 [7920/8498 (93%)]	Loss: 0.441476, Learning rate: 0.001000
# Train Epoch: 15 [8160/8498 (96%)]	Loss: 0.482675, Learning rate: 0.001000
# Train Epoch: 15 [8400/8498 (99%)]	Loss: 0.255683, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.6068, mIoU: 0.5834
#
# PSPnetLite training, epoch 16
# Train Epoch: 16 [240/8498 (3%)]	Loss: 0.584373, Learning rate: 0.001000
# Train Epoch: 16 [480/8498 (6%)]	Loss: 0.373819, Learning rate: 0.001000
# Train Epoch: 16 [720/8498 (8%)]	Loss: 0.380166, Learning rate: 0.001000
# Train Epoch: 16 [960/8498 (11%)]	Loss: 0.400348, Learning rate: 0.001000
# Train Epoch: 16 [1200/8498 (14%)]	Loss: 0.363448, Learning rate: 0.001000
# Train Epoch: 16 [1440/8498 (17%)]	Loss: 0.468845, Learning rate: 0.001000
# Train Epoch: 16 [1680/8498 (20%)]	Loss: 0.455031, Learning rate: 0.001000
# Train Epoch: 16 [1920/8498 (23%)]	Loss: 0.290561, Learning rate: 0.001000
# Train Epoch: 16 [2160/8498 (25%)]	Loss: 0.431093, Learning rate: 0.001000
# Train Epoch: 16 [2400/8498 (28%)]	Loss: 0.397775, Learning rate: 0.001000
# Train Epoch: 16 [2640/8498 (31%)]	Loss: 0.407602, Learning rate: 0.001000
# Train Epoch: 16 [2880/8498 (34%)]	Loss: 0.379362, Learning rate: 0.001000
# Train Epoch: 16 [3120/8498 (37%)]	Loss: 0.367764, Learning rate: 0.001000
# Train Epoch: 16 [3360/8498 (39%)]	Loss: 0.491232, Learning rate: 0.001000
# Train Epoch: 16 [3600/8498 (42%)]	Loss: 0.420924, Learning rate: 0.001000
# Train Epoch: 16 [3840/8498 (45%)]	Loss: 0.409228, Learning rate: 0.001000
# Train Epoch: 16 [4080/8498 (48%)]	Loss: 0.341064, Learning rate: 0.001000
# Train Epoch: 16 [4320/8498 (51%)]	Loss: 0.355216, Learning rate: 0.001000
# Train Epoch: 16 [4560/8498 (54%)]	Loss: 0.593172, Learning rate: 0.001000
# Train Epoch: 16 [4800/8498 (56%)]	Loss: 0.444247, Learning rate: 0.001000
# Train Epoch: 16 [5040/8498 (59%)]	Loss: 0.746146, Learning rate: 0.001000
# Train Epoch: 16 [5280/8498 (62%)]	Loss: 0.541460, Learning rate: 0.001000
# Train Epoch: 16 [5520/8498 (65%)]	Loss: 0.448389, Learning rate: 0.001000
# Train Epoch: 16 [5760/8498 (68%)]	Loss: 0.514964, Learning rate: 0.001000
# Train Epoch: 16 [6000/8498 (70%)]	Loss: 0.324919, Learning rate: 0.001000
# Train Epoch: 16 [6240/8498 (73%)]	Loss: 0.710169, Learning rate: 0.001000
# Train Epoch: 16 [6480/8498 (76%)]	Loss: 0.437375, Learning rate: 0.001000
# Train Epoch: 16 [6720/8498 (79%)]	Loss: 0.607283, Learning rate: 0.001000
# Train Epoch: 16 [6960/8498 (82%)]	Loss: 0.353015, Learning rate: 0.001000
# Train Epoch: 16 [7200/8498 (85%)]	Loss: 0.387944, Learning rate: 0.001000
# Train Epoch: 16 [7440/8498 (87%)]	Loss: 0.287973, Learning rate: 0.001000
# Train Epoch: 16 [7680/8498 (90%)]	Loss: 0.343438, Learning rate: 0.001000
# Train Epoch: 16 [7920/8498 (93%)]	Loss: 0.346018, Learning rate: 0.001000
# Train Epoch: 16 [8160/8498 (96%)]	Loss: 0.258410, Learning rate: 0.001000
# Train Epoch: 16 [8400/8498 (99%)]	Loss: 0.472300, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.6094, mIoU: 0.5713
#
# PSPnetLite training, epoch 17
# Train Epoch: 17 [240/8498 (3%)]	Loss: 0.399651, Learning rate: 0.001000
# Train Epoch: 17 [480/8498 (6%)]	Loss: 0.551459, Learning rate: 0.001000
# Train Epoch: 17 [720/8498 (8%)]	Loss: 0.254349, Learning rate: 0.001000
# Train Epoch: 17 [960/8498 (11%)]	Loss: 0.351002, Learning rate: 0.001000
# Train Epoch: 17 [1200/8498 (14%)]	Loss: 0.329904, Learning rate: 0.001000
# Train Epoch: 17 [1440/8498 (17%)]	Loss: 0.252817, Learning rate: 0.001000
# Train Epoch: 17 [1680/8498 (20%)]	Loss: 0.323698, Learning rate: 0.001000
# Train Epoch: 17 [1920/8498 (23%)]	Loss: 0.256905, Learning rate: 0.001000
# Train Epoch: 17 [2160/8498 (25%)]	Loss: 0.414308, Learning rate: 0.001000
# Train Epoch: 17 [2400/8498 (28%)]	Loss: 0.363955, Learning rate: 0.001000
# Train Epoch: 17 [2640/8498 (31%)]	Loss: 0.413563, Learning rate: 0.001000
# Train Epoch: 17 [2880/8498 (34%)]	Loss: 0.515882, Learning rate: 0.001000
# Train Epoch: 17 [3120/8498 (37%)]	Loss: 0.314853, Learning rate: 0.001000
# Train Epoch: 17 [3360/8498 (39%)]	Loss: 0.325858, Learning rate: 0.001000
# Train Epoch: 17 [3600/8498 (42%)]	Loss: 0.365743, Learning rate: 0.001000
# Train Epoch: 17 [3840/8498 (45%)]	Loss: 0.440886, Learning rate: 0.001000
# Train Epoch: 17 [4080/8498 (48%)]	Loss: 0.313832, Learning rate: 0.001000
# Train Epoch: 17 [4320/8498 (51%)]	Loss: 0.396670, Learning rate: 0.001000
# Train Epoch: 17 [4560/8498 (54%)]	Loss: 0.518460, Learning rate: 0.001000
# Train Epoch: 17 [4800/8498 (56%)]	Loss: 0.474316, Learning rate: 0.001000
# Train Epoch: 17 [5040/8498 (59%)]	Loss: 0.381015, Learning rate: 0.001000
# Train Epoch: 17 [5280/8498 (62%)]	Loss: 0.355334, Learning rate: 0.001000
# Train Epoch: 17 [5520/8498 (65%)]	Loss: 0.252651, Learning rate: 0.001000
# Train Epoch: 17 [5760/8498 (68%)]	Loss: 0.485885, Learning rate: 0.001000
# Train Epoch: 17 [6000/8498 (70%)]	Loss: 0.598175, Learning rate: 0.001000
# Train Epoch: 17 [6240/8498 (73%)]	Loss: 0.361053, Learning rate: 0.001000
# Train Epoch: 17 [6480/8498 (76%)]	Loss: 0.361936, Learning rate: 0.001000
# Train Epoch: 17 [6720/8498 (79%)]	Loss: 0.582807, Learning rate: 0.001000
# Train Epoch: 17 [6960/8498 (82%)]	Loss: 0.311885, Learning rate: 0.001000
# Train Epoch: 17 [7200/8498 (85%)]	Loss: 0.482778, Learning rate: 0.001000
# Train Epoch: 17 [7440/8498 (87%)]	Loss: 0.373487, Learning rate: 0.001000
# Train Epoch: 17 [7680/8498 (90%)]	Loss: 0.333431, Learning rate: 0.001000
# Train Epoch: 17 [7920/8498 (93%)]	Loss: 0.337022, Learning rate: 0.001000
# Train Epoch: 17 [8160/8498 (96%)]	Loss: 0.303783, Learning rate: 0.001000
# Train Epoch: 17 [8400/8498 (99%)]	Loss: 0.378011, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.5925, mIoU: 0.5808
#
# PSPnetLite training, epoch 18
# Train Epoch: 18 [240/8498 (3%)]	Loss: 0.378930, Learning rate: 0.001000
# Train Epoch: 18 [480/8498 (6%)]	Loss: 0.425749, Learning rate: 0.001000
# Train Epoch: 18 [720/8498 (8%)]	Loss: 0.307092, Learning rate: 0.001000
# Train Epoch: 18 [960/8498 (11%)]	Loss: 0.505185, Learning rate: 0.001000
# Train Epoch: 18 [1200/8498 (14%)]	Loss: 0.305488, Learning rate: 0.001000
# Train Epoch: 18 [1440/8498 (17%)]	Loss: 0.302351, Learning rate: 0.001000
# Train Epoch: 18 [1680/8498 (20%)]	Loss: 0.578716, Learning rate: 0.001000
# Train Epoch: 18 [1920/8498 (23%)]	Loss: 0.429935, Learning rate: 0.001000
# Train Epoch: 18 [2160/8498 (25%)]	Loss: 0.423296, Learning rate: 0.001000
# Train Epoch: 18 [2400/8498 (28%)]	Loss: 0.371860, Learning rate: 0.001000
# Train Epoch: 18 [2640/8498 (31%)]	Loss: 0.469334, Learning rate: 0.001000
# Train Epoch: 18 [2880/8498 (34%)]	Loss: 0.543364, Learning rate: 0.001000
# Train Epoch: 18 [3120/8498 (37%)]	Loss: 0.476513, Learning rate: 0.001000
# Train Epoch: 18 [3360/8498 (39%)]	Loss: 0.428917, Learning rate: 0.001000
# Train Epoch: 18 [3600/8498 (42%)]	Loss: 0.418415, Learning rate: 0.001000
# Train Epoch: 18 [3840/8498 (45%)]	Loss: 0.267094, Learning rate: 0.001000
# Train Epoch: 18 [4080/8498 (48%)]	Loss: 0.337086, Learning rate: 0.001000
# Train Epoch: 18 [4320/8498 (51%)]	Loss: 0.415118, Learning rate: 0.001000
# Train Epoch: 18 [4560/8498 (54%)]	Loss: 0.345729, Learning rate: 0.001000
# Train Epoch: 18 [4800/8498 (56%)]	Loss: 0.277985, Learning rate: 0.001000
# Train Epoch: 18 [5040/8498 (59%)]	Loss: 0.382277, Learning rate: 0.001000
# Train Epoch: 18 [5280/8498 (62%)]	Loss: 0.303621, Learning rate: 0.001000
# Train Epoch: 18 [5520/8498 (65%)]	Loss: 0.618885, Learning rate: 0.001000
# Train Epoch: 18 [5760/8498 (68%)]	Loss: 0.342817, Learning rate: 0.001000
# Train Epoch: 18 [6000/8498 (70%)]	Loss: 0.407260, Learning rate: 0.001000
# Train Epoch: 18 [6240/8498 (73%)]	Loss: 0.325366, Learning rate: 0.001000
# Train Epoch: 18 [6480/8498 (76%)]	Loss: 0.320677, Learning rate: 0.001000
# Train Epoch: 18 [6720/8498 (79%)]	Loss: 0.367847, Learning rate: 0.001000
# Train Epoch: 18 [6960/8498 (82%)]	Loss: 0.357645, Learning rate: 0.001000
# Train Epoch: 18 [7200/8498 (85%)]	Loss: 0.555743, Learning rate: 0.001000
# Train Epoch: 18 [7440/8498 (87%)]	Loss: 0.500610, Learning rate: 0.001000
# Train Epoch: 18 [7680/8498 (90%)]	Loss: 0.460096, Learning rate: 0.001000
# ...
# Train Epoch: 50 [6240/8498 (73%)]	Loss: 0.279191, Learning rate: 0.001000
# Train Epoch: 50 [6480/8498 (76%)]	Loss: 0.303568, Learning rate: 0.001000
# Train Epoch: 50 [6720/8498 (79%)]	Loss: 0.286195, Learning rate: 0.001000
# Train Epoch: 50 [6960/8498 (82%)]	Loss: 0.313299, Learning rate: 0.001000
# Train Epoch: 50 [7200/8498 (85%)]	Loss: 0.476355, Learning rate: 0.001000
# Train Epoch: 50 [7440/8498 (87%)]	Loss: 0.242390, Learning rate: 0.001000
# Train Epoch: 50 [7680/8498 (90%)]	Loss: 0.264458, Learning rate: 0.001000
# Train Epoch: 50 [7920/8498 (93%)]	Loss: 0.199192, Learning rate: 0.001000
# Train Epoch: 50 [8160/8498 (96%)]	Loss: 0.171966, Learning rate: 0.001000
# Train Epoch: 50 [8400/8498 (99%)]	Loss: 0.569120, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.6383, mIoU: 0.5852
#
# PSPnetLite training, epoch 51
# Train Epoch: 51 [240/8498 (3%)]	Loss: 0.370529, Learning rate: 0.001000
# Train Epoch: 51 [480/8498 (6%)]	Loss: 0.266912, Learning rate: 0.001000
# Train Epoch: 51 [720/8498 (8%)]	Loss: 0.315449, Learning rate: 0.001000
# Train Epoch: 51 [960/8498 (11%)]	Loss: 0.312030, Learning rate: 0.001000
# Train Epoch: 51 [1200/8498 (14%)]	Loss: 0.270022, Learning rate: 0.001000
# Train Epoch: 51 [1440/8498 (17%)]	Loss: 0.414455, Learning rate: 0.001000
# Train Epoch: 51 [1680/8498 (20%)]	Loss: 0.209445, Learning rate: 0.001000
# Train Epoch: 51 [1920/8498 (23%)]	Loss: 0.317733, Learning rate: 0.001000
# Train Epoch: 51 [2160/8498 (25%)]	Loss: 0.200295, Learning rate: 0.001000
# Train Epoch: 51 [2400/8498 (28%)]	Loss: 0.266556, Learning rate: 0.001000
# Train Epoch: 51 [2640/8498 (31%)]	Loss: 0.221317, Learning rate: 0.001000
# Train Epoch: 51 [2880/8498 (34%)]	Loss: 0.395840, Learning rate: 0.001000
# Train Epoch: 51 [3120/8498 (37%)]	Loss: 0.275601, Learning rate: 0.001000
# Train Epoch: 51 [3360/8498 (39%)]	Loss: 0.295537, Learning rate: 0.001000
# Train Epoch: 51 [3600/8498 (42%)]	Loss: 0.269878, Learning rate: 0.001000
# Train Epoch: 51 [3840/8498 (45%)]	Loss: 0.365948, Learning rate: 0.001000
# Train Epoch: 51 [4080/8498 (48%)]	Loss: 0.233763, Learning rate: 0.001000
# Train Epoch: 51 [4320/8498 (51%)]	Loss: 0.246122, Learning rate: 0.001000
# Train Epoch: 51 [4560/8498 (54%)]	Loss: 0.358472, Learning rate: 0.001000
# Train Epoch: 51 [4800/8498 (56%)]	Loss: 0.290200, Learning rate: 0.001000
# Train Epoch: 51 [5040/8498 (59%)]	Loss: 0.355222, Learning rate: 0.001000
# Train Epoch: 51 [5280/8498 (62%)]	Loss: 0.320765, Learning rate: 0.001000
# Train Epoch: 51 [5520/8498 (65%)]	Loss: 0.368171, Learning rate: 0.001000
# Train Epoch: 51 [5760/8498 (68%)]	Loss: 0.311979, Learning rate: 0.001000
# Train Epoch: 51 [6000/8498 (70%)]	Loss: 0.315050, Learning rate: 0.001000
# Train Epoch: 51 [6240/8498 (73%)]	Loss: 0.265187, Learning rate: 0.001000
# Train Epoch: 51 [6480/8498 (76%)]	Loss: 0.288131, Learning rate: 0.001000
# Train Epoch: 51 [6720/8498 (79%)]	Loss: 0.245433, Learning rate: 0.001000
# Train Epoch: 51 [6960/8498 (82%)]	Loss: 0.330762, Learning rate: 0.001000
# Train Epoch: 51 [7200/8498 (85%)]	Loss: 0.330448, Learning rate: 0.001000
# Train Epoch: 51 [7440/8498 (87%)]	Loss: 0.242573, Learning rate: 0.001000
# Train Epoch: 51 [7680/8498 (90%)]	Loss: 0.238816, Learning rate: 0.001000
# Train Epoch: 51 [7920/8498 (93%)]	Loss: 0.333730, Learning rate: 0.001000
# Train Epoch: 51 [8160/8498 (96%)]	Loss: 0.281338, Learning rate: 0.001000
# Train Epoch: 51 [8400/8498 (99%)]	Loss: 0.242593, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.6357, mIoU: 0.5814
#
# PSPnetLite training, epoch 52
# Train Epoch: 52 [240/8498 (3%)]	Loss: 0.329056, Learning rate: 0.001000
# Train Epoch: 52 [480/8498 (6%)]	Loss: 0.276702, Learning rate: 0.001000
# Train Epoch: 52 [720/8498 (8%)]	Loss: 0.343327, Learning rate: 0.001000
# Train Epoch: 52 [960/8498 (11%)]	Loss: 0.212161, Learning rate: 0.001000
# Train Epoch: 52 [1200/8498 (14%)]	Loss: 0.211008, Learning rate: 0.001000
# Train Epoch: 52 [1440/8498 (17%)]	Loss: 0.207357, Learning rate: 0.001000
# Train Epoch: 52 [1680/8498 (20%)]	Loss: 0.239435, Learning rate: 0.001000
# Train Epoch: 52 [1920/8498 (23%)]	Loss: 0.211735, Learning rate: 0.001000
# Train Epoch: 52 [2160/8498 (25%)]	Loss: 0.274758, Learning rate: 0.001000
# Train Epoch: 52 [2400/8498 (28%)]	Loss: 0.353115, Learning rate: 0.001000
# Train Epoch: 52 [2640/8498 (31%)]	Loss: 0.271694, Learning rate: 0.001000
# Train Epoch: 52 [2880/8498 (34%)]	Loss: 0.289341, Learning rate: 0.001000
# Train Epoch: 52 [3120/8498 (37%)]	Loss: 0.224340, Learning rate: 0.001000
# Train Epoch: 52 [3360/8498 (39%)]	Loss: 0.213154, Learning rate: 0.001000
# Train Epoch: 52 [3600/8498 (42%)]	Loss: 0.232496, Learning rate: 0.001000
# Train Epoch: 52 [3840/8498 (45%)]	Loss: 0.250803, Learning rate: 0.001000
# Train Epoch: 52 [4080/8498 (48%)]	Loss: 0.327350, Learning rate: 0.001000
# Train Epoch: 52 [4320/8498 (51%)]	Loss: 0.316478, Learning rate: 0.001000
# Train Epoch: 52 [4560/8498 (54%)]	Loss: 0.284883, Learning rate: 0.001000
# Train Epoch: 52 [4800/8498 (56%)]	Loss: 0.347308, Learning rate: 0.001000
# Train Epoch: 52 [5040/8498 (59%)]	Loss: 0.296315, Learning rate: 0.001000
# Train Epoch: 52 [5280/8498 (62%)]	Loss: 0.277179, Learning rate: 0.001000
# Train Epoch: 52 [5520/8498 (65%)]	Loss: 0.389505, Learning rate: 0.001000
# Train Epoch: 52 [5760/8498 (68%)]	Loss: 0.296522, Learning rate: 0.001000
# Train Epoch: 52 [6000/8498 (70%)]	Loss: 0.260445, Learning rate: 0.001000
# Train Epoch: 52 [6240/8498 (73%)]	Loss: 0.163598, Learning rate: 0.001000
# Train Epoch: 52 [6480/8498 (76%)]	Loss: 0.290674, Learning rate: 0.001000
# Train Epoch: 52 [6720/8498 (79%)]	Loss: 0.286635, Learning rate: 0.001000
# Train Epoch: 52 [6960/8498 (82%)]	Loss: 0.267588, Learning rate: 0.001000
# Train Epoch: 52 [7200/8498 (85%)]	Loss: 0.307427, Learning rate: 0.001000
# Train Epoch: 52 [7440/8498 (87%)]	Loss: 0.301237, Learning rate: 0.001000
# Train Epoch: 52 [7680/8498 (90%)]	Loss: 0.249180, Learning rate: 0.001000
# Train Epoch: 52 [7920/8498 (93%)]	Loss: 0.302044, Learning rate: 0.001000
# Train Epoch: 52 [8160/8498 (96%)]	Loss: 0.202168, Learning rate: 0.001000
# Train Epoch: 52 [8400/8498 (99%)]	Loss: 0.250766, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.6526, mIoU: 0.5789
#
# PSPnetLite training, epoch 53
# Train Epoch: 53 [240/8498 (3%)]	Loss: 0.333716, Learning rate: 0.001000
# Train Epoch: 53 [480/8498 (6%)]	Loss: 0.258856, Learning rate: 0.001000
# Train Epoch: 53 [720/8498 (8%)]	Loss: 0.249577, Learning rate: 0.001000
# Train Epoch: 53 [960/8498 (11%)]	Loss: 0.263070, Learning rate: 0.001000
# Train Epoch: 53 [1200/8498 (14%)]	Loss: 0.243889, Learning rate: 0.001000
# Train Epoch: 53 [1440/8498 (17%)]	Loss: 0.235544, Learning rate: 0.001000
# Train Epoch: 53 [1680/8498 (20%)]	Loss: 0.350713, Learning rate: 0.001000
# Train Epoch: 53 [1920/8498 (23%)]	Loss: 0.298783, Learning rate: 0.001000
# Train Epoch: 53 [2160/8498 (25%)]	Loss: 0.236405, Learning rate: 0.001000
# Train Epoch: 53 [2400/8498 (28%)]	Loss: 0.295884, Learning rate: 0.001000
# Train Epoch: 53 [2640/8498 (31%)]	Loss: 0.253894, Learning rate: 0.001000
# Train Epoch: 53 [2880/8498 (34%)]	Loss: 0.250248, Learning rate: 0.001000
# Train Epoch: 53 [3120/8498 (37%)]	Loss: 0.234211, Learning rate: 0.001000
# Train Epoch: 53 [3360/8498 (39%)]	Loss: 0.249228, Learning rate: 0.001000
# Train Epoch: 53 [3600/8498 (42%)]	Loss: 0.175535, Learning rate: 0.001000
# Train Epoch: 53 [3840/8498 (45%)]	Loss: 0.390611, Learning rate: 0.001000
# Train Epoch: 53 [4080/8498 (48%)]	Loss: 0.241163, Learning rate: 0.001000
# Train Epoch: 53 [4320/8498 (51%)]	Loss: 0.216611, Learning rate: 0.001000
# Train Epoch: 53 [4560/8498 (54%)]	Loss: 0.250382, Learning rate: 0.001000
# Train Epoch: 53 [4800/8498 (56%)]	Loss: 0.254775, Learning rate: 0.001000
# Train Epoch: 53 [5040/8498 (59%)]	Loss: 0.242655, Learning rate: 0.001000
# Train Epoch: 53 [5280/8498 (62%)]	Loss: 0.223042, Learning rate: 0.001000
# Train Epoch: 53 [5520/8498 (65%)]	Loss: 0.271323, Learning rate: 0.001000
# Train Epoch: 53 [5760/8498 (68%)]	Loss: 0.371594, Learning rate: 0.001000
# Train Epoch: 53 [6000/8498 (70%)]	Loss: 0.214032, Learning rate: 0.001000
# Train Epoch: 53 [6240/8498 (73%)]	Loss: 0.262710, Learning rate: 0.001000
# Train Epoch: 53 [6480/8498 (76%)]	Loss: 0.213991, Learning rate: 0.001000
# Train Epoch: 53 [6720/8498 (79%)]	Loss: 0.265435, Learning rate: 0.001000
# Train Epoch: 53 [6960/8498 (82%)]	Loss: 0.293022, Learning rate: 0.001000
# Train Epoch: 53 [7200/8498 (85%)]	Loss: 0.338849, Learning rate: 0.001000
# Train Epoch: 53 [7440/8498 (87%)]	Loss: 0.208044, Learning rate: 0.001000
# Train Epoch: 53 [7680/8498 (90%)]	Loss: 0.290293, Learning rate: 0.001000
# Train Epoch: 53 [7920/8498 (93%)]	Loss: 0.264870, Learning rate: 0.001000
# Train Epoch: 53 [8160/8498 (96%)]	Loss: 0.250397, Learning rate: 0.001000
# Train Epoch: 53 [8400/8498 (99%)]	Loss: 0.303332, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.6454, mIoU: 0.5800
#
# PSPnetLite training, epoch 54
# Train Epoch: 54 [240/8498 (3%)]	Loss: 0.281889, Learning rate: 0.001000
# Train Epoch: 54 [480/8498 (6%)]	Loss: 0.276448, Learning rate: 0.001000
# Train Epoch: 54 [720/8498 (8%)]	Loss: 0.230522, Learning rate: 0.001000
# Train Epoch: 54 [960/8498 (11%)]	Loss: 0.312212, Learning rate: 0.001000
# Train Epoch: 54 [1200/8498 (14%)]	Loss: 0.253310, Learning rate: 0.001000
# Train Epoch: 54 [1440/8498 (17%)]	Loss: 0.186918, Learning rate: 0.001000
# Train Epoch: 54 [1680/8498 (20%)]	Loss: 0.202833, Learning rate: 0.001000
# Train Epoch: 54 [1920/8498 (23%)]	Loss: 0.218907, Learning rate: 0.001000
# Train Epoch: 54 [2160/8498 (25%)]	Loss: 0.335475, Learning rate: 0.001000
# Train Epoch: 54 [2400/8498 (28%)]	Loss: 0.436371, Learning rate: 0.001000
# Train Epoch: 54 [2640/8498 (31%)]	Loss: 0.238965, Learning rate: 0.001000
# Train Epoch: 54 [2880/8498 (34%)]	Loss: 0.286096, Learning rate: 0.001000
# Train Epoch: 54 [3120/8498 (37%)]	Loss: 0.219017, Learning rate: 0.001000
# Train Epoch: 54 [3360/8498 (39%)]	Loss: 0.219139, Learning rate: 0.001000
# Train Epoch: 54 [3600/8498 (42%)]	Loss: 0.286077, Learning rate: 0.001000
# Train Epoch: 54 [3840/8498 (45%)]	Loss: 0.206246, Learning rate: 0.001000
# Train Epoch: 54 [4080/8498 (48%)]	Loss: 0.252989, Learning rate: 0.001000
# Train Epoch: 54 [4320/8498 (51%)]	Loss: 0.266970, Learning rate: 0.001000
# Train Epoch: 54 [4560/8498 (54%)]	Loss: 0.222250, Learning rate: 0.001000
# Train Epoch: 54 [4800/8498 (56%)]	Loss: 0.193636, Learning rate: 0.001000
# Train Epoch: 54 [5040/8498 (59%)]	Loss: 0.286944, Learning rate: 0.001000
# Train Epoch: 54 [5280/8498 (62%)]	Loss: 0.341165, Learning rate: 0.001000
# Train Epoch: 54 [5520/8498 (65%)]	Loss: 0.282413, Learning rate: 0.001000
# Train Epoch: 54 [5760/8498 (68%)]	Loss: 0.256917, Learning rate: 0.001000
# Train Epoch: 54 [6000/8498 (70%)]	Loss: 0.274461, Learning rate: 0.001000
# Train Epoch: 54 [6240/8498 (73%)]	Loss: 0.266129, Learning rate: 0.001000
# Train Epoch: 54 [6480/8498 (76%)]	Loss: 0.520078, Learning rate: 0.001000
# Train Epoch: 54 [6720/8498 (79%)]	Loss: 0.219319, Learning rate: 0.001000
# Train Epoch: 54 [6960/8498 (82%)]	Loss: 0.178283, Learning rate: 0.001000
# Train Epoch: 54 [7200/8498 (85%)]	Loss: 0.218959, Learning rate: 0.001000
# Train Epoch: 54 [7440/8498 (87%)]	Loss: 0.359899, Learning rate: 0.001000
# Train Epoch: 54 [7680/8498 (90%)]	Loss: 0.207033, Learning rate: 0.001000
# Train Epoch: 54 [7920/8498 (93%)]	Loss: 0.221923, Learning rate: 0.001000
# Train Epoch: 54 [8160/8498 (96%)]	Loss: 0.358243, Learning rate: 0.001000
# Train Epoch: 54 [8400/8498 (99%)]	Loss: 0.304214, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.5916, mIoU: 0.5951
#
# PSPnetLite training, epoch 55
# Train Epoch: 55 [240/8498 (3%)]	Loss: 0.272712, Learning rate: 0.001000
# Train Epoch: 55 [480/8498 (6%)]	Loss: 0.282685, Learning rate: 0.001000
# Train Epoch: 55 [720/8498 (8%)]	Loss: 0.291998, Learning rate: 0.001000
# Train Epoch: 55 [960/8498 (11%)]	Loss: 0.272944, Learning rate: 0.001000
# Train Epoch: 55 [1200/8498 (14%)]	Loss: 0.266781, Learning rate: 0.001000
# Train Epoch: 55 [1440/8498 (17%)]	Loss: 0.531659, Learning rate: 0.001000
# Train Epoch: 55 [1680/8498 (20%)]	Loss: 0.201324, Learning rate: 0.001000
# Train Epoch: 55 [1920/8498 (23%)]	Loss: 0.297642, Learning rate: 0.001000
# Train Epoch: 55 [2160/8498 (25%)]	Loss: 0.229034, Learning rate: 0.001000
# Train Epoch: 55 [2400/8498 (28%)]	Loss: 0.217402, Learning rate: 0.001000
# Train Epoch: 55 [2640/8498 (31%)]	Loss: 0.271737, Learning rate: 0.001000
# Train Epoch: 55 [2880/8498 (34%)]	Loss: 0.353632, Learning rate: 0.001000
# Train Epoch: 55 [3120/8498 (37%)]	Loss: 0.387899, Learning rate: 0.001000
# Train Epoch: 55 [3360/8498 (39%)]	Loss: 0.328513, Learning rate: 0.001000
# Train Epoch: 55 [3600/8498 (42%)]	Loss: 0.232835, Learning rate: 0.001000
# Train Epoch: 55 [3840/8498 (45%)]	Loss: 0.278630, Learning rate: 0.001000
# Train Epoch: 55 [4080/8498 (48%)]	Loss: 0.293638, Learning rate: 0.001000
# Train Epoch: 55 [4320/8498 (51%)]	Loss: 0.293605, Learning rate: 0.001000
# Train Epoch: 55 [4560/8498 (54%)]	Loss: 0.198201, Learning rate: 0.001000
# Train Epoch: 55 [4800/8498 (56%)]	Loss: 0.256091, Learning rate: 0.001000
# Train Epoch: 55 [5040/8498 (59%)]	Loss: 0.256318, Learning rate: 0.001000
# Train Epoch: 55 [5280/8498 (62%)]	Loss: 0.322971, Learning rate: 0.001000
# Train Epoch: 55 [5520/8498 (65%)]	Loss: 0.354449, Learning rate: 0.001000
# Train Epoch: 55 [5760/8498 (68%)]	Loss: 0.328867, Learning rate: 0.001000
# Train Epoch: 55 [6000/8498 (70%)]	Loss: 0.296316, Learning rate: 0.001000
# Train Epoch: 55 [6240/8498 (73%)]	Loss: 0.267115, Learning rate: 0.001000
# Train Epoch: 55 [6480/8498 (76%)]	Loss: 0.203636, Learning rate: 0.001000
# Train Epoch: 55 [6720/8498 (79%)]	Loss: 0.311178, Learning rate: 0.001000
# Train Epoch: 55 [6960/8498 (82%)]	Loss: 0.257739, Learning rate: 0.001000
# Train Epoch: 55 [7200/8498 (85%)]	Loss: 0.287282, Learning rate: 0.001000
# Train Epoch: 55 [7440/8498 (87%)]	Loss: 0.218385, Learning rate: 0.001000
# Train Epoch: 55 [7680/8498 (90%)]	Loss: 0.182884, Learning rate: 0.001000
# Train Epoch: 55 [7920/8498 (93%)]	Loss: 0.266086, Learning rate: 0.001000
# Train Epoch: 55 [8160/8498 (96%)]	Loss: 0.326273, Learning rate: 0.001000
# Train Epoch: 55 [8400/8498 (99%)]	Loss: 0.252681, Learning rate: 0.001000
#
# Test set (736): Average loss: 0.6313, mIoU: 0.5886
#
# PSPnetLite training, epoch 56
# Train Epoch: 56 [240/8498 (3%)]	Loss: 0.173935, Learning rate: 0.001000
# Train Epoch: 56 [480/8498 (6%)]	Loss: 0.286978, Learning rate: 0.001000
# Train Epoch: 56 [720/8498 (8%)]	Loss: 0.276721, Learning rate: 0.001000
# Train Epoch: 56 [960/8498 (11%)]	Loss: 0.246127, Learning rate: 0.001000
# Train Epoch: 56 [1200/8498 (14%)]	Loss: 0.241731, Learning rate: 0.001000
# Train Epoch: 56 [1440/8498 (17%)]	Loss: 0.274185, Learning rate: 0.001000
# Train Epoch: 56 [1680/8498 (20%)]	Loss: 0.238247, Learning rate: 0.001000
# Train Epoch: 56 [1920/8498 (23%)]	Loss: 0.261499, Learning rate: 0.001000
# Train Epoch: 56 [2160/8498 (25%)]	Loss: 0.245564, Learning rate: 0.001000
# Train Epoch: 56 [2400/8498 (28%)]	Loss: 0.176787, Learning rate: 0.001000
# Train Epoch: 56 [2640/8498 (31%)]	Loss: 0.312720, Learning rate: 0.001000
# Train Epoch: 56 [2880/8498 (34%)]	Loss: 0.289061, Learning rate: 0.001000
# Train Epoch: 56 [3120/8498 (37%)]	Loss: 0.371569, Learning rate: 0.001000
# Train Epoch: 56 [3360/8498 (39%)]	Loss: 0.221988, Learning rate: 0.001000
# Train Epoch: 56 [3600/8498 (42%)]	Loss: 0.265121, Learning rate: 0.001000
# Train Epoch: 56 [3840/8498 (45%)]	Loss: 0.217291, Learning rate: 0.001000
# Train Epoch: 56 [4080/8498 (48%)]	Loss: 0.280262, Learning rate: 0.001000
# Train Epoch: 56 [4320/8498 (51%)]	Loss: 0.324521, Learning rate: 0.001000
# Train Epoch: 56 [4560/8498 (54%)]	Loss: 0.291809, Learning rate: 0.001000
# Train Epoch: 56 [4800/8498 (56%)]	Loss: 0.209098, Learning rate: 0.001000
# Train Epoch: 56 [5040/8498 (59%)]	Loss: 0.180034, Learning rate: 0.001000
# Train Epoch: 56 [5280/8498 (62%)]	Loss: 0.215321, Learning rate: 0.001000
# Train Epoch: 56 [5520/8498 (65%)]	Loss: 0.373414, Learning rate: 0.001000
# Train Epoch: 56 [5760/8498 (68%)]	Loss: 0.233911, Learning rate: 0.001000
# Train Epoch: 56 [6000/8498 (70%)]	Loss: 0.153047, Learning rate: 0.001000

# %% [markdown]
# # Accuracy and loss curves

# %%
##Accuracy
acc_test = np.load(res_path + '/' + 'accuracy_per_epoch_val.npy')

#Loss per epoch
loss_train = np.load(res_path + '/' + 'LOSS_epoch_train.npy')
loss_test = np.load(res_path + '/' + 'LOSS_epoch_val.npy')

numEpochs = len(acc_test)
epochs = range(numEpochs)

plt.figure(1)
plt.plot(epochs, acc_test, label='Test, max acc: ' + str(np.max(acc_test)))
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')

plt.figure(2)
plt.plot(epochs, loss_test, label='Test, min loss: ' + str(np.min(loss_test)))
plt.plot(epochs, loss_train, label='Train, min loss: ' + str(np.min(loss_train)))
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# # Visualize segmentation results
# Do not expect great results.

# %%
class DeNormalize(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        for t, m, s in zip(tensor, self.mean, self.std):
            t.mul_(s).add_(m)
        return tensor


def visualizeSegmentation(args, model, device, test_loader, imageDenormalize, voc_palette):

    # switch to train mode
    model.eval()

    with torch.no_grad():
        for batch_idx, (images, mask) in enumerate(test_loader):

            images, mask = images.to(device), mask.to(device)

            outputs = model(images)

            plt.figure(batch_idx)

            for i in range(0, images.size(0)):


                image_np = (255*(imageDenormalize(images[i,...]).data.permute(1,2,0).cpu().numpy())).astype(np.uint8)
                gt_np = mask[i,...].squeeze().data.cpu().numpy()
                pred_np = outputs[i,...].data.max(0)[1].squeeze_(0).byte().cpu().numpy()

                img_pil = Image.fromarray(image_np)

                gt_np_color = np.stack((gt_np.copy(), gt_np.copy(), gt_np.copy()), axis=2)
                pred_np_color = np.stack((pred_np.copy(), pred_np.copy(), pred_np.copy()), axis=2)


                for j in range(0, 21):
                    idx_tuple = np.where(gt_np == j)
                    gt_np_color[idx_tuple[0], idx_tuple[1], 0] = colors[j][0]
                    gt_np_color[idx_tuple[0], idx_tuple[1], 1] = colors[j][1]
                    gt_np_color[idx_tuple[0], idx_tuple[1], 2] = colors[j][2]

                    idx_tuple2 = np.where(pred_np == j)
                    pred_np_color[idx_tuple2[0], idx_tuple2[1], 0] = colors[j][0]
                    pred_np_color[idx_tuple2[0], idx_tuple2[1], 1] = colors[j][1]
                    pred_np_color[idx_tuple2[0], idx_tuple2[1], 2] = colors[j][2]


                plt.subplot(args.test_batch_size, 3, i * 3 + 1)
                plt.imshow(img_pil)
                plt.subplot(args.test_batch_size, 3, i * 3 + 2)
                plt.imshow(gt_np_color)
                plt.subplot(args.test_batch_size, 3, i * 3 + 3)
                plt.imshow(pred_np_color)


            if batch_idx>7:
                plt.show()
                break

# %%
imageDenormalize = DeNormalize(mean,std)

## Color palette for visualization of the 21 classes
colors = np.array([[0, 0, 0], [128, 0, 0], [0, 128, 0], [128, 128, 0], [0, 0, 128], [128, 0, 128], [0, 128, 128],
            [128, 128, 128], [64, 0, 0], [192, 0, 0], [64, 128, 0], [192, 128, 0], [64, 0, 128], [192, 0, 128],
            [64, 128, 128], [192, 128, 128], [0, 64, 0], [128, 64, 0], [0, 192, 0], [128, 192, 0], [0, 64, 128]])

model.load_state_dict(torch.load("mySemanticSegModelPreTrained.pth"))
#model.load_state_dict(torch.load("mySemanticSegModelScratch.pth"))

print('Total params: %2.fM' % (sum(p.numel() for p in model.parameters()) / 1000000.0))

cont = 0

visualizeSegmentation(args, model, device, test_loader, imageDenormalize, colors)
